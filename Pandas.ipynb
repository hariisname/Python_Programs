# %% [markdown]
# # Pandas

# %% [markdown]
# 1. Intro
# 2. installation
# 3. importing
# 4. downloading dataset
# 5. creating DataFrames
# 6. indexing & slicing
# 7. understanding LOC & ILOC
# 8. Sorting DataFrame
# 9. Manipulating DataFrames
# 10. Removing Duplicates
# 11. handling Missing Data
# 12. data filtering and conditional changes
# 13. Export DataFrames

# %% [markdown]
# # 1. Intro
# - pandas is a software library written for the Python programming language for data manipulation and analysis.
# - The Pandas module mainly works with the tabular data
# - Pandas is capable of offering an in-memory 2d table object called DataFrame.
# - The most widely used pandas data structures are the Series(1D) and the **DataFrame(2D)** and Panel(3D).
# - Simply, a Series is similar to a single column of data while a DataFrame is similar to a sheet with rows and columns.

# %% [markdown]
# # 2. Installig
# - In Jupyter, libraries like NumPy, Pandas, etc., are pre-installed, so there's no need to install them separately. You can directly import them and use them.

# %% [markdown]
# # 3. Importing

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.1.4

# %% [markdown]
# # 4. Downloading Dataset

# %%
data = {
    'Roll_No': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120],
    'Name_of_Student': ['sundeep', 'saradhi', 'ramesh', 'suresh', 'sathwik', 'abhiram', 'srinidhi', 'lakshmi', 'dinesh', 'harish', 'murali', 'vasu', 'kali', 'ramu', 'krishna', 'hari', 'pavan', 'ashok', 'govind', 'bhargav'],
    'Telugu': [90, 50, 95, 55, 88, 73, 90, 75, 84, 83, 85, 50, 89, 25, 1, 78, 59, 85, 89, 72],
    'English': [85, 60, 78, 87, 84, 84, 83, 78, 85, 98, 86, 54, 97, 45, 25, 54, 52, 86, 89, 78],
    'Maths': [80, 75, 68, 68, 98, 91, 74, 85, 76, 81, 92, 64, 69, 60, 65, 95, 68, 98, 95, 86],
    'Science': [83, 54, 58, 64, 73, 88, 86, 64, 94, 63, 75, 87, 73, 35, 50, 67, 68, 78, 66, 64],
    'Social': [75, 78, 79, 59, 81, 84, 94, 53, 54, 79, 35, 45, 82, 48, 55, 58, 70, 44, 95, 72]
}

df = pd.DataFrame(data)
df
# Out:
#     Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 0       101         sundeep      90       85     80       83      75
# 1       102         saradhi      50       60     75       54      78
# 2       103          ramesh      95       78     68       58      79
# 3       104          suresh      55       87     68       64      59
# 4       105         sathwik      88       84     98       73      81
# 5       106         abhiram      73       84     91       88      84
# 6       107        srinidhi      90       83     74       86      94
# 7       108         lakshmi      75       78     85       64      53
# 8       109          dinesh      84       85     76       94      54
# 9       110          harish      83       98     81       63      79
# 10      111          murali      85       86     92       75      35
# 11      112            vasu      50       54     64       87      45
# 12      113            kali      89       97     69       73      82
# 13      114            ramu      25       45     60       35      48
# 14      115         krishna       1       25     65       50      55
# 15      116            hari      78       54     95       67      58
# 16      117           pavan      59       52     68       68      70
# 17      118           ashok      85       86     98       78      44
# 18      119          govind      89       89     95       66      95
# 19      120         bhargav      72       78     86       64      72

# %% [markdown]
# # 5. Creating DataFrame

# %% [markdown]
# - From CSV: Use pd.read_csv() to load CSV data.
# - From Excel: Use pd.read_excel() to load Excel data.
# - From Dictionary: Create a DataFrame directly from a dictionary using pd.DataFrame().
# - From List of Tuples: Use pd.DataFrame() with a list of tuples to create a DataFrame and specify the column names.

# %%
# 1. df_csv = pd.read_csv('file_path.csv')
# 2. df_excel = pd.read_excel('file_path.xlsx')
# 3. creating from Dictionay
import pandas as pd

# Data as a dictionary
data = {
    'Name': ['John', 'Jane', 'Alice', 'Bob'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'London', 'Berlin']
}

# Create a DataFrame from the dictionary
df_dict = pd.DataFrame(data)

# Display the DataFrame
print("Dictionay = \n",df_dict)

print('----------------------------------------------------------')
# 4. creating Dataframe using list of tuples

# Data as a list of tuples
data = [
    ('John', 28, 'New York'),
    ('Jane', 34, 'Paris'),
    ('Alice', 29, 'London'),
    ('Bob', 42, 'Berlin')
]

# Create a DataFrame from the list of tuples, and assign column names
df_tuples = pd.DataFrame(data, columns=['Name', 'Age', 'City'])

# Display the DataFrame
print("Tuples = \n",df_tuples)
# Out:
# Dictionay =
#      Name  Age      City
# 0   John   28  New York
# 1   Jane   34     Paris
# 2  Alice   29    London
# 3    Bob   42    Berlin
# ----------------------------------------------------------
# Tuples =
#      Name  Age      City
# 0   John   28  New York
# 1   Jane   34     Paris
# 2  Alice   29    London
# 3    Bob   42    Berlin

# %% [markdown]
# # 6. Indexing and Slicing

# %% [markdown]
# - head(): Displays the first n rows.
# - tail(): Displays the last n rows.
# - describe(): Provides a statistical summary of numerical columns.
# - shape: Returns the number of rows and columns.
# - Indexing with []: Access specific rows or columns.
# - Slicing with []: Slice rows with start, stop, and step.
# - iterrows(): Iterate over rows of the DataFrame.
# - iloc[] and loc[]: Access rows and columns using integer positions or labels, respectively.
# - Conditional indexing: Filter rows based on conditions.

# %%
# 1. data_frame.head(number_of_rows)
# Purpose: This method returns the first n rows of the DataFrame (by default, it returns the first 5 rows).

import pandas as pd

data = {
    'Name': ['John', 'Jane', 'Alice', 'Bob'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'London', 'Berlin']
}
df = pd.DataFrame(data)

# Get the first 2 rows of the Data
df.head(2)
# Out:
#    Name  Age      City
# 0  John   28  New York
# 1  Jane   34     Paris

# %%
# 2. data_frame.tail(number_of_rows)
# Purpose: This method returns the last n rows of the DataFrame (by default, it returns the last 5 rows).

# Get the last 2 rows of the DataFrame
df.tail(2)
# Out:
#     Name  Age    City
# 2  Alice   29  London
# 3    Bob   42  Berlin

# %%
# 3. data_frame.describe()
# Purpose: This method provides a summary of statistics for numerical columns (mean, median, standard deviation, etc.).
# Get statistical summary for numerical columns
print(df.describe())
# Out:
#              Age
# count   4.000000
# mean   33.250000
# std     6.396614
# min    28.000000
# 25%    28.750000
# 50%    31.500000
# 75%    36.000000
# max    42.000000

# %%
# 4. data_frame.shape
# Purpose: This method returns a tuple indicating the number of rows and columns in the DataFrame (rows, columns).
# Get the shape of the DataFrame
df.shape
# (4, 3)  # 4 rows and 3 columns
# Out:
# (4, 3)

# %%
# 5. Indexing with data_frame[start:stop:step]
# Purpose: This allows for slicing rows based on a specified range: start, stop, and step.
# Syntax: df[start:stop:step]
# Note: It works similarly to Python list slicing.
# Slicing rows from index 1 to 3 with a step of 1
df[1:3]
# Out:
#     Name  Age    City
# 1   Jane   34   Paris
# 2  Alice   29  London

# %%
# 6. data_frame['column_name']
# Purpose: This allows you to access a specific column in the DataFrame by its name.
# Accessing the 'Age' column
df['Age']
# Out:
# 0    28
# 1    34
# 2    29
# 3    42
# Name: Age, dtype: int64

# %%
# 7. data_frame[[column_1, column_2]]
# Purpose: This allows you to access multiple columns at once by passing a list of column names.
# Accessing both 'Name' and 'City' columns
df[['Name', 'City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Jane     Paris
# 2  Alice    London
# 3    Bob    Berlin

# %%
# 8. data_frame[[column_1, column_2]][start:stop:step]
# Purpose: This allows you to access multiple columns and slice rows at the same time.
# Accessing 'Name' and 'Age' columns and slicing rows
df[['Name', 'Age']][1:3]
# Out:
#     Name  Age
# 1   Jane   34
# 2  Alice   29

# %%
# 9. data_frame.iterrows()
# Purpose: This method iterates over the rows of the DataFrame as index and row pairs. It's typically used when you need to process each row individually.
# Note: Iterating over rows is slower than vectorized operations, so try to avoid it for large datasets.
# Iterate over rows of the DataFrame
for index, row in df.iterrows():
    print(f"Index: {index}, Name: {row['Name']}, Age: {row['Age']}")

print("----------------")
# or
for i in df.iterrows():
    print(i)
# Out:
# Index: 0, Name: John, Age: 28
# Index: 1, Name: Jane, Age: 34
# Index: 2, Name: Alice, Age: 29
# Index: 3, Name: Bob, Age: 42
# ----------------
# (0, Name        John
# Age           28
# City    New York
# Name: 0, dtype: object)
# (1, Name     Jane
# Age        34
# City    Paris
# Name: 1, dtype: object)
# (2, Name     Alice
# Age         29
# City    London
# Name: 2, dtype: object)
# (3, Name       Bob
# Age         42
# City    Berlin
# Name: 3, dtype: object)

# %% [markdown]
# # Conditional Indexing
# Conditional indexing in Pandas allows you to filter rows based on specific conditions applied to one or more columns. It is a powerful way to select and manipulate subsets of your data based on logical conditions.

# %%
# 1. Filter rows where a column's value is greater than a specific number
import pandas as pd

data = {
    'Name': ['John', 'Jane', 'Alice', 'Bob'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'London', 'Berlin']
}
df = pd.DataFrame(data)

# Filter rows where 'Age' is greater than 30
filtered_df = df[df['Age'] > 30]
filtered_df
# Out:
#    Name  Age    City
# 1  Jane   34   Paris
# 3   Bob   42  Berlin

# %%
# 2. Filter rows where a column's value is less than a specific number
# Filter rows where 'Age' is less than 30
filtered_df = df[df['Age'] < 30]
filtered_df
# Out:
#     Name  Age      City
# 0   John   28  New York
# 2  Alice   29    London

# %%
# 3. Filter rows where a column's value equals a specific value
# Filter rows where 'City' is 'Paris'
filtered_df = df[df['City'] == 'Paris']
filtered_df
# Out:
#    Name  Age   City
# 1  Jane   34  Paris

# %%
# 4. Filter rows using multiple conditions (AND)
# Filter rows where 'Age' is greater than 30 and 'City' is 'Paris'
filtered_df = df[(df['Age'] > 30) & (df['City'] == 'Paris')]
filtered_df
# Out:
#    Name  Age   City
# 1  Jane   34  Paris

# %%
# 5. Filter rows using multiple conditions (OR)
# Filter rows where 'Age' is less than 30 or 'City' is 'Berlin'
filtered_df = df[(df['Age'] < 30) | (df['City'] == 'Berlin')]
filtered_df
# Out:
#     Name  Age      City
# 0   John   28  New York
# 2  Alice   29    London
# 3    Bob   42    Berlin

# %%
# 6. Filter rows where a column's value is in a list of values
# Filter rows where 'City' is either 'Paris' or 'Berlin'
filtered_df = df[df['City'].isin(['Paris', 'Berlin'])]
filtered_df
# Out:
#    Name  Age    City
# 1  Jane   34   Paris
# 3   Bob   42  Berlin

# %%
# 7. Filter rows where a column's value is not in a list of values
# Filter rows where 'City' is not 'Paris' or 'Berlin'
filtered_df = df[~df['City'].isin(['Paris', 'Berlin'])]
filtered_df
# Out:
#     Name  Age      City
# 0   John   28  New York
# 2  Alice   29    London

# %%
# 8. Filter rows where a column's value is null (NaN)
# Create a new DataFrame with some NaN values
data = {'Name': ['John', 'Jane', 'Alice', 'Bob'],
        'Age': [28, None, 29, 42],
        'City': ['New York', None, 'London', 'Berlin']}
df = pd.DataFrame(data)

# Filter rows where 'Age' is NaN
filtered_df = df[df['Age'].isna()]
filtered_df
# Out:
#    Name  Age  City
# 1  Jane  NaN  None

# %%
# 9. Filter rows where a column's value is not null (not NaN)
# Filter rows where 'City' is not NaN
filtered_df = df[df['City'].notna()]
filtered_df
# Out:
#     Name   Age      City
# 0   John  28.0  New York
# 2  Alice  29.0    London
# 3    Bob  42.0    Berlin

# %%
# 10. Filter rows where a column’s value contains a substring (using string methods)
# Filter rows where 'City' contains the substring 'New'
# filtered_df = df[df['City'].str.contains('New')]
# print(filtered_df)
# Filter rows where 'City' contains the substring 'New', handling NaN values
filtered_df = df[df['City'].str.contains('New', na=False)]
filtered_df
# Out:
#    Name   Age      City
# 0  John  28.0  New York

# %% [markdown]
# # 7. LOC & ILOC

# %% [markdown]
# **UNDERSTANDING LOC[] (stop index included)**
#
# - data_frame.loc[row_number]
# - data_frame.loc[row_number, [column_name, ...]]
# - data_frame.loc[start:stop]
# - data_frame.loc[start:stop, "column_name"]
# - data_frame.loc[start:stop, ["column_1", "column_2", ...]]
# - data_frame.loc[start:stop, "column_1":"column_n"]
#
# **UNDERSTANDING iloc[] (stop index excluded)**
#
# - data_frame.iloc[row_number, column_number]
# - data_frame.iloc[row_start:row_stop, col_start:col_stop]
# - data_frame.iloc[start:stop, "column_number"]
# - data_frame.iloc[[row_1, row_2, ...]]
# - data_frame.iloc[:, [col_1, col_2, ...]]
# - data_frame.iloc[start:stop, [col_1, col_2, ...]]

# %% [markdown]
# ##### LOC

# %%
# 1. Accessing a single row by label
import pandas as pd

data = {
    'Name': ['John', 'Jane', 'Alice', 'Bob'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'London', 'Berlin']
}
df = pd.DataFrame(data)

# Access the row with label (index) 2
row = df.loc[2]
row
# Out:
# Name     Alice
# Age         29
# City    London
# Name: 2, dtype: object

# %%
# 2. Accessing specific rows and specific columns
# Access the row with label 1 and the columns 'Name' and 'Age'
subset = df.loc[1, ['Name', 'Age']]
subset
# Out:
# Name    Jane
# Age       34
# Name: 1, dtype: object

# %%
# 3. Slicing rows (start:stop), including the stop index
# Access rows from index 1 to 3 (stop index 3 is included)
subset = df.loc[1:3]
subset
# Out:
#     Name  Age    City
# 1   Jane   34   Paris
# 2  Alice   29  London
# 3    Bob   42  Berlin

# %%
# 4. Slicing rows (start:stop) with a specific column
# Access rows from index 1 to 3 (inclusive) and only the 'City' column
subset = df.loc[1:3, 'City']
subset
# Out:
# 1     Paris
# 2    London
# 3    Berlin
# Name: City, dtype: object

# %%
# 5. Slicing rows (start:stop) with multiple specific columns
# Access rows from index 1 to 3 (inclusive) and the columns 'Name' and 'Age'
subset = df.loc[1:3, ['Name', 'Age']]
subset
# Out:
#     Name  Age
# 1   Jane   34
# 2  Alice   29
# 3    Bob   42

# %%
# 6. Slicing rows (start:stop) with a range of columns by label
# Access rows from index 1 to 3 (inclusive) and columns from 'Name' to 'City'
subset = df.loc[1:3, 'Name':'City']
subset
# Out:
#     Name  Age    City
# 1   Jane   34   Paris
# 2  Alice   29  London
# 3    Bob   42  Berlin

# %%
# Other possible .loc[] usage:
# Modify data using .loc[]
df.loc[1, 'Age'] = 35  # Update 'Age' for row 1
df
# Out:
#     Name  Age      City
# 0   John   28  New York
# 1   Jane   35     Paris
# 2  Alice   29    London
# 3    Bob   42    Berlin

# %% [markdown]
# ##### ILOC

# %%
# 1. Accessing a specific row and column using integer positions
import pandas as pd

data = {
    'Name': ['John', 'Jane', 'Alice', 'Bob'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'London', 'Berlin']
}
df = pd.DataFrame(data)

# Access the row at index 1 and column at index 2
value = df.iloc[1, 2]
value
# Out:
# 'Paris'

# %%
# 2. Slicing rows and columns using integer positions
# Access rows from index 1 to 3 (excluding 3) and columns from index 0 to 2 (excluding 2)
subset = df.iloc[1:3, 0:2]
subset
# Out:
#     Name  Age
# 1   Jane   34
# 2  Alice   29

# %%
# 3. Slicing rows with integer positions, selecting specific columns by position
# Access rows 0 to 2 (excluding 2) and only column 2
subset = df.iloc[0:2, 2]
subset
# Out:
# 0    New York
# 1       Paris
# Name: City, dtype: object

# %%
# 4. Selecting specific rows using a list of indices
# Access rows with indices 0 and 3
subset = df.iloc[[0, 3]]
subset
# Out:
#    Name  Age      City
# 0  John   28  New York
# 3   Bob   42    Berlin

# %%
# 5. Selecting specific columns using a list of column indices
# Access all rows and only columns with indices 0 and 2
subset = df.iloc[:, [0, 2]]
subset
# Out:
#     Name      City
# 0   John  New York
# 1   Jane     Paris
# 2  Alice    London
# 3    Bob    Berlin

# %%
# 6. Slicing rows and selecting specific columns using a list
# Access rows from index 1 to 3 (excluding 3) and columns with indices 0 and 2
subset = df.iloc[1:3, [0, 2]]
subset
# Out:
#     Name    City
# 1   Jane   Paris
# 2  Alice  London

# %%
# 7. Accessing all rows for specific columns
# Access all rows for columns 1 and 2
subset = df.iloc[:, 1:3]
subset
# Out:
#    Age      City
# 0   28  New York
# 1   34     Paris
# 2   29    London
# 3   42    Berlin

# %%
# 8. Slicing rows without specifying columns
# Access rows from index 0 to 2 (excluding 2), all columns
subset = df.iloc[0:2, :]
subset
# Out:
#    Name  Age      City
# 0  John   28  New York
# 1  Jane   34     Paris

# %%
# 9. Selecting a single column as a DataFrame
# Access column 1 as a DataFrame
subset = df.iloc[:, [1]]
subset
# Out:
#    Age
# 0   28
# 1   34
# 2   29
# 3   42

# %%
# 10. Using negative indexing
# Access the last row and last column
value = df.iloc[-1, -1]
value
# Out:
# 'Berlin'

# %% [markdown]
# # 8. Sort DataFrame

# %% [markdown]
# ![image.png](attachment:360dc70e-d966-4a87-aeec-35bf6d49376c.png)

# %% [markdown]
# #### Ex: DataFrame

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 35, 30, 40],
    'Score': [85, 90, 88, 92]
}
df = pd.DataFrame(data)
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   35     90
# 2  Charlie   30     88
# 3    David   40     92

# %%
# 1. Sort by a Single Column in Ascending Order
# Sort by the 'Age' column in ascending order
sorted_df = df.sort_values("Age")
print("Sorted by Age (ascending):")
sorted_df
# Out:
# Sorted by Age (ascending):
#       Name  Age  Score
# 0    Alice   25     85
# 2  Charlie   30     88
# 1      Bob   35     90
# 3    David   40     92

# %%
# 2. Sort by a Single Column in Descending Order
# Sort by the 'Score' column in descending order
sorted_df = df.sort_values("Score", ascending=False)
print("Sorted by Score (descending):")
sorted_df
# Out:
# Sorted by Score (descending):
#       Name  Age  Score
# 3    David   40     92
# 1      Bob   35     90
# 2  Charlie   30     88
# 0    Alice   25     85

# %%
# 3. Sort by Multiple Columns in Ascending Order
# Sort by 'Age' and then by 'Score' (both ascending)
sorted_df = df.sort_values(["Age", "Score"])
print("Sorted by Age and then by Score (ascending):")
sorted_df
# Out:
# Sorted by Age and then by Score (ascending):
#       Name  Age  Score
# 0    Alice   25     85
# 2  Charlie   30     88
# 1      Bob   35     90
# 3    David   40     92

# %%
# 4. Sort by Multiple Columns with Mixed Order
# Sort by 'Age' (descending) and then by 'Score' (ascending)
sorted_df = df.sort_values(["Age", "Score"], ascending=[False, True])
print("Sorted by Age (descending) and Score (ascending):")
sorted_df
# Out:
# Sorted by Age (descending) and Score (ascending):
#       Name  Age  Score
# 3    David   40     92
# 1      Bob   35     90
# 2  Charlie   30     88
# 0    Alice   25     85

# %%
# 5. Sort by Index
# Sort the DataFrame by its index
sorted_df = df.sort_index()
print("Sorted by index:")
sorted_df
# Out:
# Sorted by index:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   35     90
# 2  Charlie   30     88
# 3    David   40     92

# %%
# 6. Sort by Column Values with Missing Data
# Add a column with missing data
df['Rank'] = [3, 1, None, 2]

# Sort by the 'Rank' column, placing NaN values at the end
sorted_df = df.sort_values("Rank", na_position="last")
print("Sorted by Rank (NaN last):")
sorted_df
# Out:
# Sorted by Rank (NaN last):
#       Name  Age  Score  Rank
# 1      Bob   35     90   1.0
# 3    David   40     92   2.0
# 0    Alice   25     85   3.0
# 2  Charlie   30     88   NaN

# %%
# 7. Sorting in Place
# Sort by 'Score' and modify the original DataFrame
df.sort_values("Score", ascending=False, inplace=True)
print("Original DataFrame after sorting in place:")
df
# Out:
# Original DataFrame after sorting in place:
#       Name  Age  Score  Rank
# 3    David   40     92   2.0
# 1      Bob   35     90   1.0
# 2  Charlie   30     88   NaN
# 0    Alice   25     85   3.0

# %% [markdown]
# # 9. Manipulating DataFrame

# %% [markdown]
# **ADDING COLUMN**
#
# - Data_frame['new_col_name']=default_value
# - Data_frame['new_col_name']=Expression / Condition
#
# **REMOVING COLUMN**
#
# - Data_frame.drop(columns="column_name")
# - Data_frame.drop(columns="column_name", inplace=True)

# %% [markdown]
# #### Creating a Sample DataFrame

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 35, 30, 40],
    'Score': [85, 90, 88, 92]
}
df = pd.DataFrame(data)
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   35     90
# 2  Charlie   30     88
# 3    David   40     92

# %%
# 1. Add a Column with a Default Value
# Add a new column 'Rank' with a default value of 1
df['Rank'] = 1
print("After adding 'Rank' with default value:")
df
# Out:
# After adding 'Rank' with default value:
#       Name  Age  Score  Rank
# 0    Alice   25     85     1
# 1      Bob   35     90     1
# 2  Charlie   30     88     1
# 3    David   40     92     1

# %%
# 2. Add a Column Using an Expression
# Add a column 'Adjusted Score' as 10% more than the 'Score'
df['Adjusted_Score'] = df['Score'] * 1.10
print("After adding 'Adjusted_Score' using an expression:")
df
# Out:
# After adding 'Adjusted_Score' using an expression:
#       Name  Age  Score  Rank  Adjusted_Score
# 0    Alice   25     85     1            93.5
# 1      Bob   35     90     1            99.0
# 2  Charlie   30     88     1            96.8
# 3    David   40     92     1           101.2

# %%
# 3. Add a Column Using a Condition
# Add a column 'Category' based on a condition
df['Category'] = ['Young' if age < 30 else 'Old' for age in df['Age']]
print("After adding 'Category' based on a condition:")
df
# Out:
# After adding 'Category' based on a condition:
#       Name  Age  Score  Rank  Adjusted_Score Category
# 0    Alice   25     85     1            93.5    Young
# 1      Bob   35     90     1            99.0      Old
# 2  Charlie   30     88     1            96.8      Old
# 3    David   40     92     1           101.2      Old

# %%
# Remove a Column Without Modifying the Original DataFrame
# Remove the 'Rank' column and return a new DataFrame
new_df = df.drop(columns='Rank')
print("After removing 'Rank' (original DataFrame remains unchanged):")
print(new_df)
print("\nOriginal DataFrame:")
df
# Out:
# After removing 'Rank' (original DataFrame remains unchanged):
#       Name  Age  Score  Adjusted_Score Category
# 0    Alice   25     85            93.5    Young
# 1      Bob   35     90            99.0      Old
# 2  Charlie   30     88            96.8      Old
# 3    David   40     92           101.2      Old
#
# Original DataFrame:
#       Name  Age  Score  Rank  Adjusted_Score Category
# 0    Alice   25     85     1            93.5    Young
# 1      Bob   35     90     1            99.0      Old
# 2  Charlie   30     88     1            96.8      Old
# 3    David   40     92     1           101.2      Old

# %%
# 5. Remove a Column and Modify the Original DataFrame
# Remove the 'Rank' column and modify the original DataFrame
df.drop(columns='Rank', inplace=True)
print("After removing 'Rank' (original DataFrame modified):")
df
# Out:
# After removing 'Rank' (original DataFrame modified):
#       Name  Age  Score  Adjusted_Score Category
# 0    Alice   25     85            93.5    Young
# 1      Bob   35     90            99.0      Old
# 2  Charlie   30     88            96.8      Old
# 3    David   40     92           101.2      Old

# %%
# 6. Add a Column Using assign
# Add a column 'Bonus' using assign (does not modify original DataFrame)
df_assigned = df.assign(Bonus=df['Score'] * 0.1)
print("After adding 'Bonus' using assign:")
df_assigned
# Out:
# After adding 'Bonus' using assign:
#       Name  Age  Score  Adjusted_Score Category  Bonus
# 0    Alice   25     85            93.5    Young    8.5
# 1      Bob   35     90            99.0      Old    9.0
# 2  Charlie   30     88            96.8      Old    8.8
# 3    David   40     92           101.2      Old    9.2

# %%
# 7. Drop Multiple Columns
# Remove multiple columns
df_dropped = df.drop(columns=['Adjusted_Score', 'Category'])
print("After removing multiple columns:")
df_dropped
# Out:
# After removing multiple columns:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   35     90
# 2  Charlie   30     88
# 3    David   40     92

# %% [markdown]
# # 10. Removing Duplicates

# %% [markdown]
# **Knowing Duplicates**
#
# - Data_frame.duplicated() - Boolean Result
#
# **Removing Duplicates**
#
# - Data_frame.drop_duplicates()
# - Data_frame.drop_duplicates(inplace=True)

# %%
# Removing Duplicates in a DataFrame
# In Pandas, duplicates can be identified and removed using specific methods. Here's a comprehensive explanation of how to work with duplicate rows.

import pandas as pd

# Sample DataFrame with duplicates
data = {
    'Name': ['Alice', 'Bob', 'Alice', 'Charlie', 'Bob', 'David'],
    'Age': [25, 35, 25, 30, 35, 40],
    'Score': [85, 90, 85, 88, 90, 92]
}
df = pd.DataFrame(data)
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   35     90
# 2    Alice   25     85
# 3  Charlie   30     88
# 4      Bob   35     90
# 5    David   40     92

# %%
# 1. Find Duplicate Rows
# Check for duplicate rows
duplicates = df.duplicated()
print("Duplicate rows (Boolean Series):")
duplicates

#Explanation:
# True indicates that the row is a duplicate of a previous row.
# The first occurrence of a duplicate row is considered unique and marked as False
# Out:
# Duplicate rows (Boolean Series):
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
# 2. Filter Only Duplicate Rows
# Display only the duplicate rows
duplicate_rows = df[df.duplicated()]
print("Duplicate Rows:")
duplicate_rows
# Out:
# Duplicate Rows:
#     Name  Age  Score
# 2  Alice   25     85
# 4    Bob   35     90

# %%
# 3. Check for Duplicates Based on Specific Columns
# Check for duplicates based only on the 'Name' column
name_duplicates = df.duplicated(subset=['Name'])
print("Duplicate rows based on 'Name':")
name_duplicates
# Out:
# Duplicate rows based on 'Name':
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
# 4. Remove Duplicates Without Modifying the Original DataFrame
# Drop duplicate rows and return a new DataFrame
df_no_duplicates = df.drop_duplicates()
print("DataFrame after removing duplicates (original unchanged):")
df_no_duplicates
# Out:
# DataFrame after removing duplicates (original unchanged):
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   35     90
# 3  Charlie   30     88
# 5    David   40     92

# %%
# 5. Remove Duplicates and Modify the Original DataFrame
# Remove duplicates and update the original DataFrame
df.drop_duplicates(inplace=True)
print("DataFrame after removing duplicates (original modified):")
df
# Out:
# DataFrame after removing duplicates (original modified):
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   35     90
# 3  Charlie   30     88
# 5    David   40     92

# %%
# 6. Remove Duplicates Based on Specific Columns
# Remove duplicates based on the 'Name' column
df_no_name_duplicates = df.drop_duplicates(subset=['Name'])
print("DataFrame after removing duplicates based on 'Name':")
df_no_name_duplicates
# Out:
# DataFrame after removing duplicates based on 'Name':
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   35     90
# 3  Charlie   30     88
# 5    David   40     92

# %%
# 7. Keep the Last Occurrence of Duplicates
# Remove duplicates but keep the last occurrence
df_last_duplicates = df.drop_duplicates(keep='last')
print("DataFrame after keeping the last occurrence of duplicates:")
df_last_duplicates
# Out:
# DataFrame after keeping the last occurrence of duplicates:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   35     90
# 3  Charlie   30     88
# 5    David   40     92

# %%
# 8. Count Total Duplicates
# Count the total number of duplicate rows
total_duplicates = df.duplicated().sum()
print(f"Total duplicate rows: {total_duplicates}")
# Out:
# Total duplicate rows: 0

# %%
# 9. Reset Index After Removing Duplicates
# Reset index after removing duplicates
df_reset_index = df.drop_duplicates().reset_index(drop=True)
print("DataFrame after removing duplicates and resetting the index:")
df_reset_index
# Out:
# DataFrame after removing duplicates and resetting the index:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   35     90
# 2  Charlie   30     88
# 3    David   40     92

# %% [markdown]
# # 11. Handling Missing Data

# %% [markdown]
# #### Creating a Sample DataFrame with Missing Data

# %%
import pandas as pd
import numpy as np

# Sample DataFrame with missing values
data = {
    'Name': ['Alice', 'Bob', np.nan, 'David', 'Eve'],
    'Age': [25, 35, np.nan, 40, 30],
    'Score': [85, np.nan, 75, 92, np.nan]
}
df = pd.DataFrame(data)
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#     Name   Age  Score
# 0  Alice  25.0   85.0
# 1    Bob  35.0    NaN
# 2    NaN   NaN   75.0
# 3  David  40.0   92.0
# 4    Eve  30.0    NaN

# %%
# 1. Remove Rows with Missing Data
# Drop rows with any missing values
df_no_missing_rows = df.dropna()
print("DataFrame after dropping rows with missing values:")
df_no_missing_rows
# Out:
# DataFrame after dropping rows with missing values:
#     Name   Age  Score
# 0  Alice  25.0   85.0
# 3  David  40.0   92.0

# %%
# 2. Remove Columns with Missing Data
# Drop columns with any missing values
df_no_missing_columns = df.dropna(axis=1)
print("DataFrame after dropping columns with missing values:")
df_no_missing_columns
# Out:
# DataFrame after dropping columns with missing values:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# 3. Remove Rows with All Missing Values
# Drop rows where all values are missing
df_no_all_missing = df.dropna(how='all')
print("DataFrame after dropping rows with all missing values:")
df_no_all_missing
# Out:
# DataFrame after dropping rows with all missing values:
#     Name   Age  Score
# 0  Alice  25.0   85.0
# 1    Bob  35.0    NaN
# 2    NaN   NaN   75.0
# 3  David  40.0   92.0
# 4    Eve  30.0    NaN

# %%
# 4. Remove Rows with Missing Data in Specific Columns
# Drop rows with missing values in the 'Score' column
df_no_missing_score = df.dropna(subset=['Score'])
print("DataFrame after dropping rows with missing values in 'Score':")
df_no_missing_score
# Out:
# DataFrame after dropping rows with missing values in 'Score':
#     Name   Age  Score
# 0  Alice  25.0   85.0
# 2    NaN   NaN   75.0
# 3  David  40.0   92.0

# %%
# 5. Modify the Original DataFrame
# Drop rows with missing values and update the original DataFrame
df.dropna(inplace=True)
print("Original DataFrame after dropping rows with missing values:")
df
# Out:
# Original DataFrame after dropping rows with missing values:
#     Name   Age  Score
# 0  Alice  25.0   85.0
# 3  David  40.0   92.0

# %%
# 6. Fill Missing Values with a Default Value
# Fill missing values with 0
df_fill_zeros = df.fillna(0)
print("DataFrame after filling missing values with 0:")
df_fill_zeros
# Out:
# DataFrame after filling missing values with 0:
#     Name   Age  Score
# 0  Alice  25.0   85.0
# 3  David  40.0   92.0

# %%
# 7. Fill Missing Values with the Mean/Median/Mode
# Fill missing values in 'Age' with the mean
df_fill_mean = df.copy()
df_fill_mean['Age'] = df_fill_mean['Age'].fillna(df_fill_mean['Age'].mean())
print("DataFrame after filling 'Age' with the mean:")
df_fill_mean
# Out:
# DataFrame after filling 'Age' with the mean:
#     Name   Age  Score
# 0  Alice  25.0   85.0
# 3  David  40.0   92.0

# %%
# 8. Fill Missing Values Using Forward Fill
# Forward fill missing values
df_ffill = df.fillna(method='ffill')
print("DataFrame after forward filling missing values:")
df_ffill
# Out:
# DataFrame after forward filling missing values:
# C:\Users\Hari\AppData\Local\Temp\ipykernel_6208\754321540.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill = df.fillna(method='ffill')
#     Name   Age  Score
# 0  Alice  25.0   85.0
# 3  David  40.0   92.0

# %%
# 9. Fill Missing Values Using Backward Fill
# Backward fill missing values
df_bfill = df.fillna(method='bfill')
print("DataFrame after backward filling missing values:")
df_bfill
# Out:
# DataFrame after backward filling missing values:
# C:\Users\Hari\AppData\Local\Temp\ipykernel_6208\3776050474.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill = df.fillna(method='bfill')
#     Name   Age  Score
# 0  Alice  25.0   85.0
# 3  David  40.0   92.0

# %%
# 10. Interpolate Missing Values
# Interpolate missing values
df_interpolated = df.interpolate()
print("DataFrame after interpolating missing values:")
df_interpolated
# Out:
# DataFrame after interpolating missing values:
# C:\Users\Hari\AppData\Local\Temp\ipykernel_6208\4038401822.py:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_interpolated = df.interpolate()
#     Name   Age  Score
# 0  Alice  25.0   85.0
# 3  David  40.0   92.0

# %%
# 11. Check for Missing Values
# Check for missing values in the DataFrame
missing_values = df.isna()
print("Missing values in the DataFrame:")
missing_values
# Out:
# Missing values in the DataFrame:
#     Name    Age  Score
# 0  False  False  False
# 3  False  False  False

# %%
# 12. Count Total Missing Values
# Count total missing values in each column
missing_count = df.isna().sum()
print("Total missing values in each column:")
missing_count
# Out:
# Total missing values in each column:
# Name     0
# Age      0
# Score    0
# dtype: int64

# %% [markdown]
# # 12. Data iltering & Conditional Changes

# %% [markdown]
# ### Creating a DataFrame
# **Columns:**
#   * ID: Unique identifier for each row (1 to 200).
#   * Name: Names like "Person_1", with some NaN values introduced.
#   * Age: Random ages between 18 and 59, with some NaN values.
#   * City: Random selection from cities ("New York", "London", "Paris", "Berlin") and NaN values.
#   * Score: Random floating-point numbers between 0 and 100, with some NaN values.
#   * Group: Random selection from groups ("A", "B", "C", "D").
#   * Join_Date: Random dates starting from "2020-01-01".
#   * Is_Active: Boolean values randomly set to True or False.

# %%
import pandas as pd
import numpy as np
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# Creating a DataFrame with 200 rows for testing various operations
np.random.seed(42)  # For reproducible results

data = {
    'ID': range(1, 201),
    'Name': [f'Person_{i}' if i % 10 != 0 else np.nan for i in range(1, 201)],  # Introducing some NaN values
    'Age': [np.random.randint(18, 60) if i % 15 != 0 else np.nan for i in range(1, 201)],  # Random ages with NaN values
    'City': [np.random.choice(['New York', 'London', 'Paris', 'Berlin', np.nan]) for _ in range(200)],
    'Score': [np.random.uniform(0, 100) if i % 20 != 0 else np.nan for i in range(1, 201)],  # Random scores with NaN values
    'Group': [np.random.choice(['A', 'B', 'C', 'D']) for _ in range(200)],
    'Join_Date': [pd.Timestamp('2020-01-01') + pd.to_timedelta(np.random.randint(0, 1000), unit='D') for _ in range(200)],
    'Is_Active': [np.random.choice([True, False]) for _ in range(200)]
}

# Create the DataFrame
test_df = pd.DataFrame(data)

# Save the DataFrame to verify its structure
# test_df.to_csv('/mnt/data/sample_dataframe.csv', index=False)
test_df
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 3      4    Person_4  25.0     Paris  54.922666     C 2021-12-30       True
# 4      5    Person_5  38.0    London  71.459592     D 2022-03-23       True
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 195  196  Person_196  34.0       nan  81.379502     A 2020-01-13      False
# 196  197  Person_197  19.0  New York  68.473117     A 2020-06-16       True
# 197  198  Person_198  19.0    Berlin  16.261694     D 2021-10-03      False
# 198  199  Person_199  45.0       nan  91.092718     B 2021-08-18       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True
#
# [200 rows x 8 columns]

# %%
test_df.head()
# Out:
#    ID      Name   Age      City      Score Group  Join_Date  Is_Active
# 0   1  Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 1   2  Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2   3  Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 3   4  Person_4  25.0     Paris  54.922666     C 2021-12-30       True
# 4   5  Person_5  38.0    London  71.459592     D 2022-03-23       True

# %%
# 1) Filter rows where Age is greater than 30:
df_filtered = test_df[test_df['Age'] > 30]
df_filtered
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 4      5    Person_5  38.0    London  71.459592     D 2022-03-23       True
# 5      6    Person_6  56.0       nan  66.019738     A 2022-07-11       True
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 190  191  Person_191  56.0    Berlin  97.439481     A 2020-09-17       True
# 193  194  Person_194  54.0       nan  53.609637     B 2020-06-20       True
# 195  196  Person_196  34.0       nan  81.379502     A 2020-01-13      False
# 198  199  Person_199  45.0       nan  91.092718     B 2021-08-18       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True
#
# [131 rows x 8 columns]

# %%
# 2.Select rows where City is "London":
df_filtered = test_df[test_df['City'] == 'London']
df_filtered
# Out:
#       ID        Name   Age    City      Score Group  Join_Date  Is_Active
# 4      5    Person_5  38.0  London  71.459592     D 2022-03-23       True
# 7      8    Person_8  40.0  London  95.486528     A 2022-03-04      False
# 14    15   Person_15   NaN  London  75.784611     A 2020-12-15       True
# 27    28   Person_28  44.0  London  43.385165     B 2021-11-22       True
# 34    35   Person_35  54.0  London  50.313626     A 2021-04-18       True
# 40    41   Person_41  21.0  London  64.241928     A 2020-12-30      False
# 41    42   Person_42  42.0  London   2.651131     A 2021-10-27      False
# 44    45   Person_45   NaN  London  57.547418     B 2020-11-07       True
# 49    50         NaN  24.0  London  94.146481     A 2022-07-07      False
# 72    73   Person_73  31.0  London  28.203457     A 2020-05-05       True
# 73    74   Person_74  40.0  London  17.743954     D 2022-03-22       True
# 74    75   Person_75   NaN  London  75.061475     D 2021-06-20       True
# 94    95   Person_95  28.0  London   1.083765     B 2022-01-17       True
# 126  127  Person_127  18.0  London  82.186006     B 2021-10-25       True
# 128  129  Person_129  43.0  London   8.134878     D 2020-05-16      False
# 129  130         NaN  31.0  London   8.483771     C 2022-01-28      False
# 131  132  Person_132  44.0  London  37.427080     B 2020-08-30       True
# 132  133  Person_133  26.0  London  37.064215     C 2021-06-26      False
# 134  135  Person_135   NaN  London  94.724858     C 2020-08-16       True
# 135  136  Person_136  32.0  London  98.600106     A 2021-07-01       True
# 136  137  Person_137  43.0  London  75.337819     A 2022-07-08      False
# 142  143  Person_143  21.0  London  42.422201     B 2020-03-15       True
# 143  144  Person_144  47.0  London  90.635439     A 2020-01-04       True
# 145  146  Person_146  40.0  London  49.262510     D 2021-10-07      False
# 149  150         NaN   NaN  London  11.881792     B 2021-05-18       True
# 158  159  Person_159  23.0  London  22.359584     C 2020-01-26       True
# 159  160         NaN  45.0  London        NaN     C 2021-03-10       True
# 162  163  Person_163  47.0  London  96.987883     C 2021-10-06       True
# 164  165  Person_165   NaN  London  89.114311     C 2021-02-13      False
# 165  166  Person_166  45.0  London  52.770111     C 2020-04-27       True
# 168  169  Person_169  50.0  London  55.385428     D 2021-12-24      False
# 184  185  Person_185  32.0  London  27.738118     C 2022-04-24       True
# 186  187  Person_187  49.0  London  46.369840     A 2021-11-03       True
# 191  192  Person_192  19.0  London  98.621074     B 2022-07-07      False
# 192  193  Person_193  20.0  London  69.816171     A 2021-10-11       True
# 194  195  Person_195   NaN  London  30.952762     A 2022-06-16      False

# %%
# 3.Find rows where Score is less than 50 and Group is "A":
df_filtered = test_df[(test_df['Score'] < 50) & (test_df['Group'] == 'A')]
df_filtered
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 15    16   Person_16  20.0     Paris   1.439349     A 2020-04-16      False
# 18    19   Person_19  41.0    Berlin   4.072880     A 2021-07-26      False
# 24    25   Person_25  29.0     Paris  49.161588     A 2021-09-16      False
# 26    27   Person_27  42.0     Paris  17.320187     A 2020-09-09       True
# 37    38   Person_38  26.0    Berlin  16.293443     A 2020-03-18       True
# 41    42   Person_42  42.0    London   2.651131     A 2021-10-27      False
# 47    48   Person_48  37.0    Berlin  45.825289     A 2020-01-03       True
# 54    55   Person_55  53.0     Paris   6.936130     A 2020-09-30      False
# 55    56   Person_56  57.0  New York  10.077800     A 2021-05-20       True
# 56    57   Person_57  21.0  New York   1.822183     A 2022-03-16      False
# 60    61   Person_61  59.0    Berlin   7.118865     A 2020-07-10      False
# 61    62   Person_62  21.0  New York  31.897563     A 2022-09-11      False
# 63    64   Person_64  35.0     Paris   2.327194     A 2021-04-29       True
# 65    66   Person_66  51.0    Berlin  28.185477     A 2021-12-14      False
# 72    73   Person_73  31.0    London  28.203457     A 2020-05-05       True
# 96    97   Person_97  25.0  New York   9.128668     A 2021-07-07       True
# 97    98   Person_98  52.0    Berlin  31.931364     A 2021-02-28      False
# 103  104  Person_104  58.0    Berlin  44.844552     A 2022-01-07      False
# 104  105  Person_105   NaN     Paris  29.321077     A 2021-03-18       True
# 125  126  Person_126  20.0     Paris   7.276301     A 2021-08-29      False
# 137  138  Person_138  59.0  New York  37.625959     A 2020-08-10      False
# 147  148  Person_148  32.0       nan  46.866064     A 2022-05-30       True
# 150  151  Person_151  53.0  New York  11.752625     A 2022-09-24      False
# 173  174  Person_174  20.0       nan  45.454106     A 2021-07-12      False
# 178  179  Person_179  26.0    Berlin  28.096319     A 2021-07-03      False
# 185  186  Person_186  49.0    Berlin  18.812116     A 2020-09-15      False
# 186  187  Person_187  49.0    London  46.369840     A 2021-11-03       True
# 194  195  Person_195   NaN    London  30.952762     A 2022-06-16      False

# %%
# 4. Filter rows where Age is between 25 and 40, and Is_Active is True:
df_filtered = test_df[(test_df['Age'] >= 25) & (test_df['Age'] <= 40) & (test_df['Is_Active'] == True)]
df_filtered
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 3      4    Person_4  25.0     Paris  54.922666     C 2021-12-30       True
# 4      5    Person_5  38.0    London  71.459592     D 2022-03-23       True
# 6      7    Person_7  36.0    Berlin  27.993390     C 2020-03-13       True
# 9     10         NaN  28.0     Paris  55.435405     B 2020-02-16       True
# 22    23   Person_23  38.0    Berlin  47.417383     D 2020-09-13       True
# 36    37   Person_37  38.0     Paris  65.869363     B 2022-09-09       True
# 37    38   Person_38  26.0    Berlin  16.293443     A 2020-03-18       True
# 42    43   Person_43  31.0     Paris  58.577558     D 2021-06-09       True
# 43    44   Person_44  26.0    Berlin  94.023024     C 2021-11-29       True
# 47    48   Person_48  37.0    Berlin  45.825289     A 2020-01-03       True
# 52    53   Person_53  31.0       nan  90.535064     A 2022-01-20       True
# 53    54   Person_54  34.0       nan  19.579113     C 2021-05-22       True
# 63    64   Person_64  35.0     Paris   2.327194     A 2021-04-29       True
# 66    67   Person_67  27.0    Berlin  11.816483     C 2020-02-08       True
# 68    69   Person_69  31.0  New York  62.894285     A 2020-09-29       True
# 70    71   Person_71  32.0  New York  73.507104     B 2020-03-26       True
# 71    72   Person_72  25.0       nan  80.348093     A 2021-04-18       True
# 72    73   Person_73  31.0    London  28.203457     A 2020-05-05       True
# 73    74   Person_74  40.0    London  17.743954     D 2022-03-22       True
# 78    79   Person_79  35.0    Berlin  37.201809     D 2020-01-25       True
# 88    89   Person_89  26.0     Paris  90.255291     D 2021-04-14       True
# 94    95   Person_95  28.0    London   1.083765     B 2022-01-17       True
# 95    96   Person_96  34.0       nan  90.538198     C 2021-08-17       True
# 96    97   Person_97  25.0  New York   9.128668     A 2021-07-07       True
# 107  108  Person_108  26.0    Berlin  75.237453     C 2022-05-26       True
# 108  109  Person_109  25.0    Berlin  79.157904     C 2022-08-23       True
# 109  110         NaN  29.0       nan  78.961814     C 2022-01-10       True
# 117  118  Person_118  39.0       nan  11.706702     B 2021-05-17       True
# 124  125  Person_125  31.0  New York  70.096913     D 2020-12-15       True
# 133  134  Person_134  32.0     Paris  81.279957     B 2020-02-09       True
# 135  136  Person_136  32.0    London  98.600106     A 2021-07-01       True
# 138  139  Person_139  30.0  New York   8.350072     D 2020-01-06       True
# 147  148  Person_148  32.0       nan  46.866064     A 2022-05-30       True
# 151  152  Person_152  30.0    Berlin  64.921030     B 2022-08-04       True
# 171  172  Person_172  30.0       nan  62.939864     D 2020-04-22       True
# 184  185  Person_185  32.0    London  27.738118     C 2022-04-24       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True

# %%
# 5.Select rows where City is either "New York" or "Paris":
df_filtered = test_df[test_df['City'].isin(['New York', 'Paris'])]
df_filtered
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 3      4    Person_4  25.0     Paris  54.922666     C 2021-12-30       True
# 9     10         NaN  28.0     Paris  55.435405     B 2020-02-16       True
# 10    11   Person_11  41.0     Paris  61.172075     D 2020-04-30       True
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 187  188  Person_188  41.0     Paris  35.335223     B 2022-06-20      False
# 188  189  Person_189  58.0  New York  58.365611     D 2021-11-20       True
# 189  190         NaN  29.0     Paris   7.773464     B 2020-01-10      False
# 196  197  Person_197  19.0  New York  68.473117     A 2020-06-16       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True
#
# [86 rows x 8 columns]

# %%
# 6.Find rows where the Name starts with "Person_1":
df_filtered = test_df[test_df['Name'].str.startswith('Person_1', na=False)]
df_filtered
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 10    11   Person_11  41.0     Paris  61.172075     D 2020-04-30       True
# 11    12   Person_12  53.0  New York  41.960006     B 2020-08-01      False
# 12    13   Person_13  57.0       nan  24.773099     B 2020-08-26       True
# 13    14   Person_14  41.0    Berlin  35.597268     C 2020-02-25       True
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 194  195  Person_195   NaN    London  30.952762     A 2022-06-16      False
# 195  196  Person_196  34.0       nan  81.379502     A 2020-01-13      False
# 196  197  Person_197  19.0  New York  68.473117     A 2020-06-16       True
# 197  198  Person_198  19.0    Berlin  16.261694     D 2021-10-03      False
# 198  199  Person_199  45.0       nan  91.092718     B 2021-08-18       True
#
# [100 rows x 8 columns]

# %%
# 7. Filter rows where City contains the substring "New":
df_filtered = test_df[test_df['City'].str.contains('New', na=False)]
df_filtered
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 11    12   Person_12  53.0  New York  41.960006     B 2020-08-01      False
# 16    17   Person_17  39.0  New York  11.607264     C 2022-04-10      False
# 17    18   Person_18  19.0  New York   4.600264     D 2020-02-17      False
# 32    33   Person_33  32.0  New York  37.461261     C 2021-12-26      False
# 33    34   Person_34  20.0  New York  62.585992     A 2021-06-09      False
# 35    36   Person_36  24.0  New York  85.648984     A 2020-01-28      False
# 38    39   Person_39  56.0  New York   7.056875     C 2020-08-03       True
# 39    40         NaN  35.0  New York        NaN     C 2021-01-20      False
# 45    46   Person_46  43.0  New York  38.816993     D 2022-06-01       True
# 48    49   Person_49  45.0  New York  54.561679     C 2021-09-14      False
# 50    51   Person_51  25.0  New York  38.610264     B 2022-01-19      False
# 55    56   Person_56  57.0  New York  10.077800     A 2021-05-20       True
# 56    57   Person_57  21.0  New York   1.822183     A 2022-03-16      False
# 61    62   Person_62  21.0  New York  31.897563     A 2022-09-11      False
# 64    65   Person_65  43.0  New York  81.446848     B 2020-01-28       True
# 68    69   Person_69  31.0  New York  62.894285     A 2020-09-29       True
# 70    71   Person_71  32.0  New York  73.507104     B 2020-03-26       True
# 77    78   Person_78  33.0  New York  41.261768     C 2020-07-30      False
# 79    80         NaN  41.0  New York        NaN     C 2021-08-02      False
# 81    82   Person_82  42.0  New York  34.080354     B 2020-03-07       True
# 85    86   Person_86  18.0  New York  75.087107     C 2020-04-20      False
# 86    87   Person_87  42.0  New York  75.454287     C 2020-08-15       True
# 96    97   Person_97  25.0  New York   9.128668     A 2021-07-07       True
# 98    99   Person_99  52.0  New York  95.006197     D 2021-09-04      False
# 105  106  Person_106  45.0  New York  32.866455     B 2022-08-09       True
# 106  107  Person_107  24.0  New York  67.251846     B 2020-11-10       True
# 113  114  Person_114  41.0  New York  54.952888     B 2021-10-23      False
# 116  117  Person_117  57.0  New York  35.091501     B 2021-08-04       True
# 120  121  Person_121  52.0  New York  76.151063     C 2020-12-15      False
# 124  125  Person_125  31.0  New York  70.096913     D 2020-12-15       True
# 127  128  Person_128  22.0  New York  70.624223     A 2022-04-02      False
# 137  138  Person_138  59.0  New York  37.625959     A 2020-08-10      False
# 138  139  Person_139  30.0  New York   8.350072     D 2020-01-06       True
# 139  140         NaN  49.0  New York        NaN     B 2020-11-17      False
# 146  147  Person_147  56.0  New York   1.135364     D 2020-04-27      False
# 150  151  Person_151  53.0  New York  11.752625     A 2022-09-24      False
# 154  155  Person_155  39.0  New York  96.217255     C 2020-07-12      False
# 161  162  Person_162  37.0  New York   1.215447     C 2020-10-26      False
# 166  167  Person_167  42.0  New York  99.296480     B 2022-04-15      False
# 172  173  Person_173  58.0  New York  69.574869     D 2020-05-19      False
# 188  189  Person_189  58.0  New York  58.365611     D 2021-11-20       True
# 196  197  Person_197  19.0  New York  68.473117     A 2020-06-16       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True

# %%
# 8. Select rows where Age is NaN (missing):
df_filtered = test_df[test_df['Age'].isna()]
df_filtered
# Out:
#       ID        Name  Age    City      Score Group  Join_Date  Is_Active
# 14    15   Person_15  NaN  London  75.784611     A 2020-12-15       True
# 29    30         NaN  NaN   Paris  61.585010     A 2020-10-29      False
# 44    45   Person_45  NaN  London  57.547418     B 2020-11-07       True
# 59    60         NaN  NaN   Paris        NaN     C 2020-01-15       True
# 74    75   Person_75  NaN  London  75.061475     D 2021-06-20       True
# 89    90         NaN  NaN   Paris  50.525237     A 2020-02-03      False
# 104  105  Person_105  NaN   Paris  29.321077     A 2021-03-18       True
# 119  120         NaN  NaN  Berlin        NaN     C 2021-05-30       True
# 134  135  Person_135  NaN  London  94.724858     C 2020-08-16       True
# 149  150         NaN  NaN  London  11.881792     B 2021-05-18       True
# 164  165  Person_165  NaN  London  89.114311     C 2021-02-13      False
# 179  180         NaN  NaN     nan        NaN     D 2022-03-15      False
# 194  195  Person_195  NaN  London  30.952762     A 2022-06-16      False

# %%
# 9. Find rows where City is not null:
df_filtered = test_df[test_df['City'].notna()]
df_filtered
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 3      4    Person_4  25.0     Paris  54.922666     C 2021-12-30       True
# 4      5    Person_5  38.0    London  71.459592     D 2022-03-23       True
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 195  196  Person_196  34.0       nan  81.379502     A 2020-01-13      False
# 196  197  Person_197  19.0  New York  68.473117     A 2020-06-16       True
# 197  198  Person_198  19.0    Berlin  16.261694     D 2021-10-03      False
# 198  199  Person_199  45.0       nan  91.092718     B 2021-08-18       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True
#
# [200 rows x 8 columns]

# %%
# 10 Add a new column Status:

test_df['Status'] = test_df['Score'].apply(lambda x: 'High' if x > 75 else 'Low')
test_df
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 3      4    Person_4  25.0     Paris  54.922666     C 2021-12-30       True
# 4      5    Person_5  38.0    London  71.459592     D 2022-03-23       True
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 195  196  Person_196  34.0       nan  81.379502     A 2020-01-13      False
# 196  197  Person_197  19.0  New York  68.473117     A 2020-06-16       True
# 197  198  Person_198  19.0    Berlin  16.261694     D 2021-10-03      False
# 198  199  Person_199  45.0       nan  91.092718     B 2021-08-18       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True
#
#     Status
# 0      Low
# 1      Low
# 2      Low
# 3      Low
# 4      Low
# ..     ...
# 195   High
# 196    Low
# 197    Low
# 198   High
# 199    Low
#
# [200 rows x 9 columns]

# %%
# 11. Update City to "Unknown" where it is null:
test_df['City'] = test_df['City'].fillna('Unknown')
test_df
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 3      4    Person_4  25.0     Paris  54.922666     C 2021-12-30       True
# 4      5    Person_5  38.0    London  71.459592     D 2022-03-23       True
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 195  196  Person_196  34.0       nan  81.379502     A 2020-01-13      False
# 196  197  Person_197  19.0  New York  68.473117     A 2020-06-16       True
# 197  198  Person_198  19.0    Berlin  16.261694     D 2021-10-03      False
# 198  199  Person_199  45.0       nan  91.092718     B 2021-08-18       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True
#
#     Status
# 0      Low
# 1      Low
# 2      Low
# 3      Low
# 4      Low
# ..     ...
# 195   High
# 196    Low
# 197    Low
# 198   High
# 199    Low
#
# [200 rows x 9 columns]

# %%
# 12. Set Group to "VIP" for rows where Score is greater than 90:

test_df.loc[test_df['Score'] > 90, 'Group'] = 'VIP'
test_df[test_df['Group']=='VIP']
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 7      8    Person_8  40.0    London  95.486528   VIP 2022-03-04      False
# 43    44   Person_44  26.0    Berlin  94.023024   VIP 2021-11-29       True
# 49    50         NaN  24.0    London  94.146481   VIP 2022-07-07      False
# 51    52   Person_52  52.0    Berlin  96.119056   VIP 2020-12-28      False
# 52    53   Person_53  31.0       nan  90.535064   VIP 2022-01-20       True
# 76    77   Person_77  38.0       nan  99.050514   VIP 2021-06-08      False
# 82    83   Person_83  58.0       nan  93.075733   VIP 2020-08-20       True
# 88    89   Person_89  26.0     Paris  90.255291   VIP 2021-04-14       True
# 95    96   Person_96  34.0       nan  90.538198   VIP 2021-08-17       True
# 98    99   Person_99  52.0  New York  95.006197   VIP 2021-09-04      False
# 100  101  Person_101  22.0    Berlin  95.060715   VIP 2021-11-22       True
# 130  131  Person_131  56.0     Paris  98.663958   VIP 2022-06-17       True
# 134  135  Person_135   NaN    London  94.724858   VIP 2020-08-16       True
# 135  136  Person_136  32.0    London  98.600106   VIP 2021-07-01       True
# 143  144  Person_144  47.0    London  90.635439   VIP 2020-01-04       True
# 154  155  Person_155  39.0  New York  96.217255   VIP 2020-07-12      False
# 160  161  Person_161  45.0     Paris  96.322254   VIP 2020-06-21      False
# 162  163  Person_163  47.0    London  96.987883   VIP 2021-10-06       True
# 166  167  Person_167  42.0  New York  99.296480   VIP 2022-04-15      False
# 169  170         NaN  18.0     Paris  96.930254   VIP 2020-08-12       True
# 176  177  Person_177  25.0    Berlin  90.115801   VIP 2021-10-15      False
# 180  181  Person_181  54.0    Berlin  95.041148   VIP 2022-06-12       True
# 190  191  Person_191  56.0    Berlin  97.439481   VIP 2020-09-17       True
# 191  192  Person_192  19.0    London  98.621074   VIP 2022-07-07      False
# 198  199  Person_199  45.0       nan  91.092718   VIP 2021-08-18       True
#
#     Status
# 7     High
# 43    High
# 49    High
# 51    High
# 52    High
# 76    High
# 82    High
# 88    High
# 95    High
# 98    High
# 100   High
# 130   High
# 134   High
# 135   High
# 143   High
# 154   High
# 160   High
# 162   High
# 166   High
# 169   High
# 176   High
# 180   High
# 190   High
# 191   High
# 198   High

# %%
# 13. Update Age to the mean of the Age column for rows where it is null:
mean_age = test_df['Age'].mean(skipna=True)
test_df.loc[test_df['Age'].isna(), 'Age'] = mean_age

test_df
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 3      4    Person_4  25.0     Paris  54.922666     C 2021-12-30       True
# 4      5    Person_5  38.0    London  71.459592     D 2022-03-23       True
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 195  196  Person_196  34.0       nan  81.379502     A 2020-01-13      False
# 196  197  Person_197  19.0  New York  68.473117     A 2020-06-16       True
# 197  198  Person_198  19.0    Berlin  16.261694     D 2021-10-03      False
# 198  199  Person_199  45.0       nan  91.092718   VIP 2021-08-18       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True
#
#     Status
# 0      Low
# 1      Low
# 2      Low
# 3      Low
# 4      Low
# ..     ...
# 195   High
# 196    Low
# 197    Low
# 198   High
# 199    Low
#
# [200 rows x 9 columns]

# %%
# 14. Select rows where Age is greater than 40 and City is not null:

df_filtered = test_df[(test_df['Age'] > 40) & (test_df['City'].notna())]
df_filtered
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 5      6    Person_6  56.0       nan  66.019738     A 2022-07-11       True
# 10    11   Person_11  41.0     Paris  61.172075     D 2020-04-30       True
# 11    12   Person_12  53.0  New York  41.960006     B 2020-08-01      False
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 187  188  Person_188  41.0     Paris  35.335223     B 2022-06-20      False
# 188  189  Person_189  58.0  New York  58.365611     D 2021-11-20       True
# 190  191  Person_191  56.0    Berlin  97.439481   VIP 2020-09-17       True
# 193  194  Person_194  54.0       nan  53.609637     B 2020-06-20       True
# 198  199  Person_199  45.0       nan  91.092718   VIP 2021-08-18       True
#
#     Status
# 0      Low
# 1      Low
# 5      Low
# 10     Low
# 11     Low
# ..     ...
# 187    Low
# 188    Low
# 190   High
# 193    Low
# 198   High
#
# [93 rows x 9 columns]

# %%
# 15. Filter rows where Group is "B" and Is_Active is False:

df_filtered = test_df[(test_df['Group'] == 'B') & (test_df['Is_Active'] == False)]
df_filtered
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 8      9    Person_9  28.0    Berlin  73.789692     B 2020-09-05      False
# 11    12   Person_12  53.0  New York  41.960006     B 2020-08-01      False
# 19    20         NaN  47.0     Paris        NaN     B 2020-12-02      False
# 21    22   Person_22  19.0     Paris  70.365786     B 2022-03-14      False
# 30    31   Person_31  45.0    Berlin  63.509365     B 2021-09-30      False
# 50    51   Person_51  25.0  New York  38.610264     B 2022-01-19      False
# 57    58   Person_58  19.0     Paris   9.444296     B 2022-01-08      False
# 58    59   Person_59  23.0     Paris  68.300677     B 2022-06-01      False
# 62    63   Person_63  46.0    Berlin  84.487531     B 2021-09-22      False
# 80    81   Person_81  43.0    Berlin  77.641296     B 2021-01-28      False
# 84    85   Person_85  32.0     Paris  42.899403     B 2020-05-25      False
# 90    91   Person_91  41.0       nan  82.645747     B 2021-09-14      False
# 113  114  Person_114  41.0  New York  54.952888     B 2021-10-23      False
# 114  115  Person_115  54.0       nan  44.153050     B 2020-10-03      False
# 115  116  Person_116  52.0       nan  88.770418     B 2021-12-10      False
# 118  119  Person_119  44.0     Paris  14.299168     B 2021-09-15      False
# 139  140         NaN  49.0  New York        NaN     B 2020-11-17      False
# 153  154  Person_154  24.0    Berlin  58.336877     B 2021-03-16      False
# 187  188  Person_188  41.0     Paris  35.335223     B 2022-06-20      False
# 189  190         NaN  29.0     Paris   7.773464     B 2020-01-10      False
#
#     Status
# 8      Low
# 11     Low
# 19     Low
# 21     Low
# 30     Low
# 50     Low
# 57     Low
# 58     Low
# 62    High
# 80    High
# 84     Low
# 90    High
# 113    Low
# 114    Low
# 115   High
# 118    Low
# 139    Low
# 153    Low
# 187    Low
# 189    Low

# %%
 # 16. Retrieve rows with indices from 50 to 70 where Score is greater than 80:
df_filtered = test_df.iloc[50:71][test_df['Score'] > 80]
df_filtered
# Out:
#     ID       Name   Age      City      Score Group  Join_Date  Is_Active  \
# 51  52  Person_52  52.0    Berlin  96.119056   VIP 2020-12-28      False
# 52  53  Person_53  31.0       nan  90.535064   VIP 2022-01-20       True
# 62  63  Person_63  46.0    Berlin  84.487531     B 2021-09-22      False
# 64  65  Person_65  43.0  New York  81.446848     B 2020-01-28       True
# 69  70        NaN  48.0     Paris  87.747201     D 2020-08-18       True
#
#    Status
# 51   High
# 52   High
# 62   High
# 64   High
# 69   High

# %%
# 17. Find rows where Join_Date is after "2022-01-01":
df_filtered = test_df[test_df['Join_Date'] > '2022-01-01']
df_filtered
# Out:
#       ID        Name        Age      City      Score Group  Join_Date  \
# 1      2    Person_2  46.000000  New York  15.643704     B 2022-08-02
# 4      5    Person_5  38.000000    London  71.459592     D 2022-03-23
# 5      6    Person_6  56.000000       nan  66.019738     A 2022-07-11
# 7      8    Person_8  40.000000    London  95.486528   VIP 2022-03-04
# 16    17   Person_17  39.000000  New York  11.607264     C 2022-04-10
# 21    22   Person_22  19.000000     Paris  70.365786     B 2022-03-14
# 25    26   Person_26  39.000000    Berlin  47.347177     C 2022-05-16
# 36    37   Person_37  38.000000     Paris  65.869363     B 2022-09-09
# 45    46   Person_46  43.000000  New York  38.816993     D 2022-06-01
# 49    50         NaN  24.000000    London  94.146481   VIP 2022-07-07
# 50    51   Person_51  25.000000  New York  38.610264     B 2022-01-19
# 52    53   Person_53  31.000000       nan  90.535064   VIP 2022-01-20
# 56    57   Person_57  21.000000  New York   1.822183     A 2022-03-16
# 57    58   Person_58  19.000000     Paris   9.444296     B 2022-01-08
# 58    59   Person_59  23.000000     Paris  68.300677     B 2022-06-01
# 61    62   Person_62  21.000000  New York  31.897563     A 2022-09-11
# 67    68   Person_68  53.000000     Paris  69.673717     A 2022-08-10
# 73    74   Person_74  40.000000    London  17.743954     D 2022-03-22
# 91    92   Person_92  18.000000     Paris  32.004960     D 2022-02-14
# 92    93   Person_93  25.000000     Paris  89.552323     A 2022-07-24
# 94    95   Person_95  28.000000    London   1.083765     B 2022-01-17
# 103  104  Person_104  58.000000    Berlin  44.844552     A 2022-01-07
# 105  106  Person_106  45.000000  New York  32.866455     B 2022-08-09
# 107  108  Person_108  26.000000    Berlin  75.237453     C 2022-05-26
# 108  109  Person_109  25.000000    Berlin  79.157904     C 2022-08-23
# 109  110         NaN  29.000000       nan  78.961814     C 2022-01-10
# 121  122  Person_122  18.000000    Berlin  61.821806     C 2022-04-22
# 123  124  Person_124  54.000000       nan   8.410681     B 2022-04-09
# 127  128  Person_128  22.000000  New York  70.624223     A 2022-04-02
# 129  130         NaN  31.000000    London   8.483771     C 2022-01-28
# 130  131  Person_131  56.000000     Paris  98.663958   VIP 2022-06-17
# 136  137  Person_137  43.000000    London  75.337819     A 2022-07-08
# 144  145  Person_145  54.000000     Paris  11.119748     D 2022-04-26
# 147  148  Person_148  32.000000       nan  46.866064     A 2022-05-30
# 150  151  Person_151  53.000000  New York  11.752625     A 2022-09-24
# 151  152  Person_152  30.000000    Berlin  64.921030     B 2022-08-04
# 155  156  Person_156  45.000000    Berlin  37.487058     C 2022-04-26
# 166  167  Person_167  42.000000  New York  99.296480   VIP 2022-04-15
# 167  168  Person_168  56.000000    Berlin   7.379656     D 2022-02-25
# 179  180         NaN  38.823529       nan        NaN     D 2022-03-15
# 180  181  Person_181  54.000000    Berlin  95.041148   VIP 2022-06-12
# 183  184  Person_184  41.000000       nan  62.013260     C 2022-05-17
# 184  185  Person_185  32.000000    London  27.738118     C 2022-04-24
# 187  188  Person_188  41.000000     Paris  35.335223     B 2022-06-20
# 191  192  Person_192  19.000000    London  98.621074   VIP 2022-07-07
# 194  195  Person_195  38.823529    London  30.952762     A 2022-06-16
#
#      Is_Active Status
# 1         True    Low
# 4         True    Low
# 5         True    Low
# 7        False   High
# 16       False    Low
# 21       False    Low
# 25       False    Low
# 36        True    Low
# 45        True    Low
# 49       False   High
# 50       False    Low
# 52        True   High
# 56       False    Low
# 57       False    Low
# 58       False    Low
# 61       False    Low
# 67        True    Low
# 73        True    Low
# 91       False    Low
# 92       False   High
# 94        True    Low
# 103      False    Low
# 105       True    Low
# 107       True   High
# 108       True   High
# 109       True   High
# 121      False    Low
# 123       True    Low
# 127      False    Low
# 129      False    Low
# 130       True   High
# 136      False   High
# 144      False    Low
# 147       True    Low
# 150      False    Low
# 151       True    Low
# 155      False    Low
# 166      False   High
# 167      False    Low
# 179      False    Low
# 180       True   High
# 183      False    Low
# 184       True    Low
# 187      False    Low
# 191      False   High
# 194      False    Low

# %%
# 18. Select rows where Score is in the top 10% of the entire dataset:

threshold = test_df['Score'].quantile(0.9)
df_filtered = test_df[test_df['Score'] > threshold]
df_filtered
# Out:
#       ID        Name        Age      City      Score Group  Join_Date  \
# 7      8    Person_8  40.000000    London  95.486528   VIP 2022-03-04
# 43    44   Person_44  26.000000    Berlin  94.023024   VIP 2021-11-29
# 49    50         NaN  24.000000    London  94.146481   VIP 2022-07-07
# 51    52   Person_52  52.000000    Berlin  96.119056   VIP 2020-12-28
# 76    77   Person_77  38.000000       nan  99.050514   VIP 2021-06-08
# 82    83   Person_83  58.000000       nan  93.075733   VIP 2020-08-20
# 98    99   Person_99  52.000000  New York  95.006197   VIP 2021-09-04
# 100  101  Person_101  22.000000    Berlin  95.060715   VIP 2021-11-22
# 130  131  Person_131  56.000000     Paris  98.663958   VIP 2022-06-17
# 134  135  Person_135  38.823529    London  94.724858   VIP 2020-08-16
# 135  136  Person_136  32.000000    London  98.600106   VIP 2021-07-01
# 154  155  Person_155  39.000000  New York  96.217255   VIP 2020-07-12
# 160  161  Person_161  45.000000     Paris  96.322254   VIP 2020-06-21
# 162  163  Person_163  47.000000    London  96.987883   VIP 2021-10-06
# 166  167  Person_167  42.000000  New York  99.296480   VIP 2022-04-15
# 169  170         NaN  18.000000     Paris  96.930254   VIP 2020-08-12
# 180  181  Person_181  54.000000    Berlin  95.041148   VIP 2022-06-12
# 190  191  Person_191  56.000000    Berlin  97.439481   VIP 2020-09-17
# 191  192  Person_192  19.000000    London  98.621074   VIP 2022-07-07
#
#      Is_Active Status
# 7        False   High
# 43        True   High
# 49       False   High
# 51       False   High
# 76       False   High
# 82        True   High
# 98       False   High
# 100       True   High
# 130       True   High
# 134       True   High
# 135       True   High
# 154      False   High
# 160      False   High
# 162       True   High
# 166      False   High
# 169       True   High
# 180       True   High
# 190       True   High
# 191      False   High

# %%
# 19. Create a new column Category:

def categorize_age(age):
    if age < 30:
        return 'Youth'
    elif 30 <= age <= 50:
        return 'Adult'
    else:
        return 'Senior'

test_df['Category'] = test_df['Age'].apply(categorize_age)
test_df
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 3      4    Person_4  25.0     Paris  54.922666     C 2021-12-30       True
# 4      5    Person_5  38.0    London  71.459592     D 2022-03-23       True
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 195  196  Person_196  34.0       nan  81.379502     A 2020-01-13      False
# 196  197  Person_197  19.0  New York  68.473117     A 2020-06-16       True
# 197  198  Person_198  19.0    Berlin  16.261694     D 2021-10-03      False
# 198  199  Person_199  45.0       nan  91.092718   VIP 2021-08-18       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True
#
#     Status Category
# 0      Low   Senior
# 1      Low    Adult
# 2      Low    Adult
# 3      Low    Youth
# 4      Low    Adult
# ..     ...      ...
# 195   High    Adult
# 196    Low    Youth
# 197    Low    Youth
# 198   High    Adult
# 199    Low    Adult
#
# [200 rows x 10 columns]

# %%
# 20. Filter rows where the Name column length is greater than 8 characters:
df_filtered = test_df[test_df['Name'].str.len() > 8]
df_filtered
# Out:
#       ID        Name        Age      City      Score Group  Join_Date  \
# 10    11   Person_11  41.000000     Paris  61.172075     D 2020-04-30
# 11    12   Person_12  53.000000  New York  41.960006     B 2020-08-01
# 12    13   Person_13  57.000000       nan  24.773099     B 2020-08-26
# 13    14   Person_14  41.000000    Berlin  35.597268     C 2020-02-25
# 14    15   Person_15  38.823529    London  75.784611     A 2020-12-15
# ..   ...         ...        ...       ...        ...   ...        ...
# 194  195  Person_195  38.823529    London  30.952762     A 2022-06-16
# 195  196  Person_196  34.000000       nan  81.379502     A 2020-01-13
# 196  197  Person_197  19.000000  New York  68.473117     A 2020-06-16
# 197  198  Person_198  19.000000    Berlin  16.261694     D 2021-10-03
# 198  199  Person_199  45.000000       nan  91.092718   VIP 2021-08-18
#
#      Is_Active Status Category
# 10        True    Low    Adult
# 11       False    Low   Senior
# 12        True    Low   Senior
# 13        True    Low    Adult
# 14        True   High    Adult
# ..         ...    ...      ...
# 194      False    Low    Adult
# 195      False   High    Adult
# 196       True    Low    Youth
# 197      False    Low    Youth
# 198       True   High    Adult
#
# [171 rows x 10 columns]

# %%
df=test_df

# %%
# 1. Filter rows where Score is between the 25th and 75th percentile and Is_Active is True.
q1 = df[(df['Score'].between(df['Score'].quantile(0.25), df['Score'].quantile(0.75))) & (df['Is_Active'] == True)]
q1
# Out:
#       ID        Name        Age      City      Score Group  Join_Date  \
# 2      3    Person_3  32.000000  New York  25.024290     B 2020-03-18
# 3      4    Person_4  25.000000     Paris  54.922666     C 2021-12-30
# 4      5    Person_5  38.000000    London  71.459592     D 2022-03-23
# 5      6    Person_6  56.000000       nan  66.019738     A 2022-07-11
# 6      7    Person_7  36.000000    Berlin  27.993390     C 2020-03-13
# 9     10         NaN  28.000000     Paris  55.435405     B 2020-02-16
# 10    11   Person_11  41.000000     Paris  61.172075     D 2020-04-30
# 13    14   Person_14  41.000000    Berlin  35.597268     C 2020-02-25
# 22    23   Person_23  38.000000    Berlin  47.417383     D 2020-09-13
# 27    28   Person_28  44.000000    London  43.385165     B 2021-11-22
# 28    29   Person_29  59.000000     Paris  39.850473     C 2021-12-19
# 34    35   Person_35  54.000000    London  50.313626     A 2021-04-18
# 36    37   Person_37  38.000000     Paris  65.869363     B 2022-09-09
# 42    43   Person_43  31.000000     Paris  58.577558     D 2021-06-09
# 44    45   Person_45  38.823529    London  57.547418     B 2020-11-07
# 45    46   Person_46  43.000000  New York  38.816993     D 2022-06-01
# 46    47   Person_47  19.000000    Berlin  64.328822     A 2020-01-07
# 47    48   Person_48  37.000000    Berlin  45.825289     A 2020-01-03
# 67    68   Person_68  53.000000     Paris  69.673717     A 2022-08-10
# 68    69   Person_69  31.000000  New York  62.894285     A 2020-09-29
# 70    71   Person_71  32.000000  New York  73.507104     B 2020-03-26
# 72    73   Person_73  31.000000    London  28.203457     A 2020-05-05
# 74    75   Person_75  38.823529    London  75.061475     D 2021-06-20
# 78    79   Person_79  35.000000    Berlin  37.201809     D 2020-01-25
# 81    82   Person_82  42.000000  New York  34.080354     B 2020-03-07
# 86    87   Person_87  42.000000  New York  75.454287     C 2020-08-15
# 93    94   Person_94  41.000000     Paris  38.920168     B 2021-01-03
# 102  103  Person_103  56.000000     Paris  63.183721     C 2020-11-15
# 104  105  Person_105  38.823529     Paris  29.321077     A 2021-03-18
# 105  106  Person_106  45.000000  New York  32.866455     B 2022-08-09
# 106  107  Person_107  24.000000  New York  67.251846     B 2020-11-10
# 107  108  Person_108  26.000000    Berlin  75.237453     C 2022-05-26
# 116  117  Person_117  57.000000  New York  35.091501     B 2021-08-04
# 124  125  Person_125  31.000000  New York  70.096913     D 2020-12-15
# 131  132  Person_132  44.000000    London  37.427080     B 2020-08-30
# 141  142  Person_142  49.000000       nan  55.840425     A 2022-01-01
# 142  143  Person_143  21.000000    London  42.422201     B 2020-03-15
# 147  148  Person_148  32.000000       nan  46.866064     A 2022-05-30
# 151  152  Person_152  30.000000    Berlin  64.921030     B 2022-08-04
# 165  166  Person_166  45.000000    London  52.770111     C 2020-04-27
# 170  171  Person_171  44.000000    Berlin  52.309784     D 2021-06-15
# 171  172  Person_172  30.000000       nan  62.939864     D 2020-04-22
# 174  175  Person_175  56.000000    Berlin  62.755808     C 2020-01-01
# 182  183  Person_183  59.000000    Berlin  45.565675     B 2021-05-25
# 184  185  Person_185  32.000000    London  27.738118     C 2022-04-24
# 186  187  Person_187  49.000000    London  46.369840     A 2021-11-03
# 188  189  Person_189  58.000000  New York  58.365611     D 2021-11-20
# 192  193  Person_193  20.000000    London  69.816171     A 2021-10-11
# 193  194  Person_194  54.000000       nan  53.609637     B 2020-06-20
# 196  197  Person_197  19.000000  New York  68.473117     A 2020-06-16
#
#      Is_Active Status Category
# 2         True    Low    Adult
# 3         True    Low    Youth
# 4         True    Low    Adult
# 5         True    Low   Senior
# 6         True    Low    Adult
# 9         True    Low    Youth
# 10        True    Low    Adult
# 13        True    Low    Adult
# 22        True    Low    Adult
# 27        True    Low    Adult
# 28        True    Low   Senior
# 34        True    Low   Senior
# 36        True    Low    Adult
# 42        True    Low    Adult
# 44        True    Low    Adult
# 45        True    Low    Adult
# 46        True    Low    Youth
# 47        True    Low    Adult
# 67        True    Low   Senior
# 68        True    Low    Adult
# 70        True    Low    Adult
# 72        True    Low    Adult
# 74        True   High    Adult
# 78        True    Low    Adult
# 81        True    Low    Adult
# 86        True   High    Adult
# 93        True    Low    Adult
# 102       True    Low   Senior
# 104       True    Low    Adult
# 105       True    Low    Adult
# 106       True    Low    Youth
# 107       True   High    Youth
# 116       True    Low   Senior
# 124       True    Low    Adult
# 131       True    Low    Adult
# 141       True    Low    Adult
# 142       True    Low    Youth
# 147       True    Low    Adult
# 151       True    Low    Adult
# 165       True    Low    Adult
# 170       True    Low    Adult
# 171       True    Low    Adult
# 174       True    Low   Senior
# 182       True    Low   Senior
# 184       True    Low    Adult
# 186       True    Low    Adult
# 188       True    Low   Senior
# 192       True    Low    Youth
# 193       True    Low   Senior
# 196       True    Low    Youth

# %%
# 2. Find rows where City is not "Unknown" and Age is greater than the average Age of the dataset.
q2 = df[(df['City'] != "Unknown") & (df['Age'] > df['Age'].mean())]
q2
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 5      6    Person_6  56.0       nan  66.019738     A 2022-07-11       True
# 7      8    Person_8  40.0    London  95.486528   VIP 2022-03-04      False
# 10    11   Person_11  41.0     Paris  61.172075     D 2020-04-30       True
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 188  189  Person_189  58.0  New York  58.365611     D 2021-11-20       True
# 190  191  Person_191  56.0    Berlin  97.439481   VIP 2020-09-17       True
# 193  194  Person_194  54.0       nan  53.609637     B 2020-06-20       True
# 198  199  Person_199  45.0       nan  91.092718   VIP 2021-08-18       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True
#
#     Status Category
# 0      Low   Senior
# 1      Low    Adult
# 5      Low   Senior
# 7     High    Adult
# 10     Low    Adult
# ..     ...      ...
# 188    Low   Senior
# 190   High   Senior
# 193    Low   Senior
# 198   High    Adult
# 199    Low    Adult
#
# [102 rows x 10 columns]

# %%
# 3. Select rows where Name ends with "5" and City contains the substring "New".
q3 = df[df['Name'].str.endswith('5') & df['City'].str.contains('New', na=False)]
q3
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 64    65   Person_65  43.0  New York  81.446848     B 2020-01-28       True
# 124  125  Person_125  31.0  New York  70.096913     D 2020-12-15       True
# 154  155  Person_155  39.0  New York  96.217255   VIP 2020-07-12      False
#
#     Status Category
# 64    High    Adult
# 124    Low    Adult
# 154   High    Adult

# %%
# 4. Find rows where City has a length greater than 6 characters.
q4 = df[df['City'].str.len() > 6]
q4
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 11    12   Person_12  53.0  New York  41.960006     B 2020-08-01      False
# 16    17   Person_17  39.0  New York  11.607264     C 2022-04-10      False
# 17    18   Person_18  19.0  New York   4.600264     D 2020-02-17      False
# 32    33   Person_33  32.0  New York  37.461261     C 2021-12-26      False
# 33    34   Person_34  20.0  New York  62.585992     A 2021-06-09      False
# 35    36   Person_36  24.0  New York  85.648984     A 2020-01-28      False
# 38    39   Person_39  56.0  New York   7.056875     C 2020-08-03       True
# 39    40         NaN  35.0  New York        NaN     C 2021-01-20      False
# 45    46   Person_46  43.0  New York  38.816993     D 2022-06-01       True
# 48    49   Person_49  45.0  New York  54.561679     C 2021-09-14      False
# 50    51   Person_51  25.0  New York  38.610264     B 2022-01-19      False
# 55    56   Person_56  57.0  New York  10.077800     A 2021-05-20       True
# 56    57   Person_57  21.0  New York   1.822183     A 2022-03-16      False
# 61    62   Person_62  21.0  New York  31.897563     A 2022-09-11      False
# 64    65   Person_65  43.0  New York  81.446848     B 2020-01-28       True
# 68    69   Person_69  31.0  New York  62.894285     A 2020-09-29       True
# 70    71   Person_71  32.0  New York  73.507104     B 2020-03-26       True
# 77    78   Person_78  33.0  New York  41.261768     C 2020-07-30      False
# 79    80         NaN  41.0  New York        NaN     C 2021-08-02      False
# 81    82   Person_82  42.0  New York  34.080354     B 2020-03-07       True
# 85    86   Person_86  18.0  New York  75.087107     C 2020-04-20      False
# 86    87   Person_87  42.0  New York  75.454287     C 2020-08-15       True
# 96    97   Person_97  25.0  New York   9.128668     A 2021-07-07       True
# 98    99   Person_99  52.0  New York  95.006197   VIP 2021-09-04      False
# 105  106  Person_106  45.0  New York  32.866455     B 2022-08-09       True
# 106  107  Person_107  24.0  New York  67.251846     B 2020-11-10       True
# 113  114  Person_114  41.0  New York  54.952888     B 2021-10-23      False
# 116  117  Person_117  57.0  New York  35.091501     B 2021-08-04       True
# 120  121  Person_121  52.0  New York  76.151063     C 2020-12-15      False
# 124  125  Person_125  31.0  New York  70.096913     D 2020-12-15       True
# 127  128  Person_128  22.0  New York  70.624223     A 2022-04-02      False
# 137  138  Person_138  59.0  New York  37.625959     A 2020-08-10      False
# 138  139  Person_139  30.0  New York   8.350072     D 2020-01-06       True
# 139  140         NaN  49.0  New York        NaN     B 2020-11-17      False
# 146  147  Person_147  56.0  New York   1.135364     D 2020-04-27      False
# 150  151  Person_151  53.0  New York  11.752625     A 2022-09-24      False
# 154  155  Person_155  39.0  New York  96.217255   VIP 2020-07-12      False
# 161  162  Person_162  37.0  New York   1.215447     C 2020-10-26      False
# 166  167  Person_167  42.0  New York  99.296480   VIP 2022-04-15      False
# 172  173  Person_173  58.0  New York  69.574869     D 2020-05-19      False
# 188  189  Person_189  58.0  New York  58.365611     D 2021-11-20       True
# 196  197  Person_197  19.0  New York  68.473117     A 2020-06-16       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True
#
#     Status Category
# 1      Low    Adult
# 2      Low    Adult
# 11     Low   Senior
# 16     Low    Adult
# 17     Low    Youth
# 32     Low    Adult
# 33     Low    Youth
# 35    High    Youth
# 38     Low   Senior
# 39     Low    Adult
# 45     Low    Adult
# 48     Low    Adult
# 50     Low    Youth
# 55     Low   Senior
# 56     Low    Youth
# 61     Low    Youth
# 64    High    Adult
# 68     Low    Adult
# 70     Low    Adult
# 77     Low    Adult
# 79     Low    Adult
# 81     Low    Adult
# 85    High    Youth
# 86    High    Adult
# 96     Low    Youth
# 98    High   Senior
# 105    Low    Adult
# 106    Low    Youth
# 113    Low    Adult
# 116    Low   Senior
# 120   High   Senior
# 124    Low    Adult
# 127    Low    Youth
# 137    Low   Senior
# 138    Low    Adult
# 139    Low    Adult
# 146    Low   Senior
# 150    Low   Senior
# 154   High    Adult
# 161    Low    Adult
# 166   High    Adult
# 172    Low   Senior
# 188    Low   Senior
# 196    Low    Youth
# 199    Low    Adult

# %%
# 5. Filter rows where Join_Date falls on a weekend (Saturday or Sunday).
q5 = df[df['Join_Date'].dt.dayofweek >= 5]
q5
# Out:
#       ID        Name        Age      City      Score Group  Join_Date  \
# 8      9    Person_9  28.000000    Berlin  73.789692     B 2020-09-05
# 9     10         NaN  28.000000     Paris  55.435405     B 2020-02-16
# 11    12   Person_12  53.000000  New York  41.960006     B 2020-08-01
# 16    17   Person_17  39.000000  New York  11.607264     C 2022-04-10
# 20    21   Person_21  55.000000       nan  85.546058     A 2020-01-26
# 22    23   Person_23  38.000000    Berlin  47.417383     D 2020-09-13
# 28    29   Person_29  59.000000     Paris  39.850473     C 2021-12-19
# 32    33   Person_33  32.000000  New York  37.461261     C 2021-12-26
# 34    35   Person_35  54.000000    London  50.313626     A 2021-04-18
# 44    45   Person_45  38.823529    London  57.547418     B 2020-11-07
# 53    54   Person_54  34.000000       nan  19.579113     C 2021-05-22
# 57    58   Person_58  19.000000     Paris   9.444296     B 2022-01-08
# 61    62   Person_62  21.000000  New York  31.897563     A 2022-09-11
# 66    67   Person_67  27.000000    Berlin  11.816483     C 2020-02-08
# 71    72   Person_72  25.000000       nan  80.348093     A 2021-04-18
# 74    75   Person_75  38.823529    London  75.061475     D 2021-06-20
# 75    76   Person_76  57.000000     Paris  80.683474     B 2020-05-24
# 78    79   Person_79  35.000000    Berlin  37.201809     D 2020-01-25
# 81    82   Person_82  42.000000  New York  34.080354     B 2020-03-07
# 83    84   Person_84  46.000000    Berlin  85.841275     B 2020-04-18
# 86    87   Person_87  42.000000  New York  75.454287     C 2020-08-15
# 92    93   Person_93  25.000000     Paris  89.552323     A 2022-07-24
# 93    94   Person_94  41.000000     Paris  38.920168     B 2021-01-03
# 97    98   Person_98  52.000000    Berlin  31.931364     A 2021-02-28
# 98    99   Person_99  52.000000  New York  95.006197   VIP 2021-09-04
# 102  103  Person_103  56.000000     Paris  63.183721     C 2020-11-15
# 113  114  Person_114  41.000000  New York  54.952888     B 2021-10-23
# 114  115  Person_115  54.000000       nan  44.153050     B 2020-10-03
# 119  120         NaN  38.823529    Berlin        NaN     C 2021-05-30
# 122  123  Person_123  52.000000       nan  10.112268     C 2021-03-21
# 123  124  Person_124  54.000000       nan   8.410681     B 2022-04-09
# 125  126  Person_126  20.000000     Paris   7.276301     A 2021-08-29
# 127  128  Person_128  22.000000  New York  70.624223     A 2022-04-02
# 128  129  Person_129  43.000000    London   8.134878     D 2020-05-16
# 131  132  Person_132  44.000000    London  37.427080     B 2020-08-30
# 132  133  Person_133  26.000000    London  37.064215     C 2021-06-26
# 133  134  Person_134  32.000000     Paris  81.279957     B 2020-02-09
# 134  135  Person_135  38.823529    London  94.724858   VIP 2020-08-16
# 141  142  Person_142  49.000000       nan  55.840425     A 2022-01-01
# 142  143  Person_143  21.000000    London  42.422201     B 2020-03-15
# 143  144  Person_144  47.000000    London  90.635439   VIP 2020-01-04
# 148  149  Person_149  46.000000    Berlin   5.630328     B 2021-08-28
# 150  151  Person_151  53.000000  New York  11.752625     A 2022-09-24
# 154  155  Person_155  39.000000  New York  96.217255   VIP 2020-07-12
# 158  159  Person_159  23.000000    London  22.359584     C 2020-01-26
# 160  161  Person_161  45.000000     Paris  96.322254   VIP 2020-06-21
# 163  164  Person_164  28.000000       nan   4.315991     D 2020-11-21
# 164  165  Person_165  38.823529    London  89.114311     C 2021-02-13
# 177  178  Person_178  44.000000       nan   4.544638     C 2020-11-15
# 178  179  Person_179  26.000000    Berlin  28.096319     A 2021-07-03
# 180  181  Person_181  54.000000    Berlin  95.041148   VIP 2022-06-12
# 184  185  Person_185  32.000000    London  27.738118     C 2022-04-24
# 188  189  Person_189  58.000000  New York  58.365611     D 2021-11-20
# 193  194  Person_194  54.000000       nan  53.609637     B 2020-06-20
# 197  198  Person_198  19.000000    Berlin  16.261694     D 2021-10-03
#
#      Is_Active Status Category
# 8        False    Low    Youth
# 9         True    Low    Youth
# 11       False    Low   Senior
# 16       False    Low    Adult
# 20        True   High   Senior
# 22        True    Low    Adult
# 28        True    Low   Senior
# 32       False    Low    Adult
# 34        True    Low   Senior
# 44        True    Low    Adult
# 53        True    Low    Adult
# 57       False    Low    Youth
# 61       False    Low    Youth
# 66        True    Low    Youth
# 71        True   High    Youth
# 74        True   High    Adult
# 75        True   High   Senior
# 78        True    Low    Adult
# 81        True    Low    Adult
# 83        True   High    Adult
# 86        True   High    Adult
# 92       False   High    Youth
# 93        True    Low    Adult
# 97       False    Low   Senior
# 98       False   High   Senior
# 102       True    Low   Senior
# 113      False    Low    Adult
# 114      False    Low   Senior
# 119       True    Low    Adult
# 122       True    Low   Senior
# 123       True    Low   Senior
# 125      False    Low    Youth
# 127      False    Low    Youth
# 128      False    Low    Adult
# 131       True    Low    Adult
# 132      False    Low    Youth
# 133       True   High    Adult
# 134       True   High    Adult
# 141       True    Low    Adult
# 142       True    Low    Youth
# 143       True   High    Adult
# 148       True    Low    Adult
# 150      False    Low   Senior
# 154      False   High    Adult
# 158       True    Low    Youth
# 160      False   High    Adult
# 163      False    Low    Youth
# 164      False   High    Adult
# 177      False    Low    Adult
# 178      False    Low    Youth
# 180       True   High   Senior
# 184       True    Low    Adult
# 188       True    Low   Senior
# 193       True    Low   Senior
# 197      False    Low    Youth

# %%
# 6. Select rows where Join_Date is in the past 6 months from today.
from datetime import datetime, timedelta
six_months_ago = datetime.now() - timedelta(days=180)
q6 = df[df['Join_Date'] >= six_months_ago]
q6
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, City, Score, Group, Join_Date, Is_Active, Status, Category]
# Index: []

# %%
# 7. Find rows where Score is missing, and Age is less than 30.
q7 = df[df['Score'].isna() & (df['Age'] < 30)]
q7
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, City, Score, Group, Join_Date, Is_Active, Status, Category]
# Index: []

# %%
# 8. Replace NaN values in the City column with the most frequently occurring city.
most_frequent_city = df['City'].mode()[0]
df['City'].fillna(most_frequent_city, inplace=True)
df
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 3      4    Person_4  25.0     Paris  54.922666     C 2021-12-30       True
# 4      5    Person_5  38.0    London  71.459592     D 2022-03-23       True
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 195  196  Person_196  34.0       nan  81.379502     A 2020-01-13      False
# 196  197  Person_197  19.0  New York  68.473117     A 2020-06-16       True
# 197  198  Person_198  19.0    Berlin  16.261694     D 2021-10-03      False
# 198  199  Person_199  45.0       nan  91.092718   VIP 2021-08-18       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True
#
#     Status Category
# 0      Low   Senior
# 1      Low    Adult
# 2      Low    Adult
# 3      Low    Youth
# 4      Low    Adult
# ..     ...      ...
# 195   High    Adult
# 196    Low    Youth
# 197    Low    Youth
# 198   High    Adult
# 199    Low    Adult
#
# [200 rows x 10 columns]

# %%
# 9. Create a column Performance that assigns "Excellent" if Score > 90, "Good" if between 60-90, and "Needs Improvement" otherwise.
df['Performance'] = df['Score'].apply(lambda x: 'Excellent' if x > 90 else 'Good' if x >= 60 else 'Needs Improvement')
df
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 3      4    Person_4  25.0     Paris  54.922666     C 2021-12-30       True
# 4      5    Person_5  38.0    London  71.459592     D 2022-03-23       True
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 195  196  Person_196  34.0       nan  81.379502     A 2020-01-13      False
# 196  197  Person_197  19.0  New York  68.473117     A 2020-06-16       True
# 197  198  Person_198  19.0    Berlin  16.261694     D 2021-10-03      False
# 198  199  Person_199  45.0       nan  91.092718   VIP 2021-08-18       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True
#
#     Status Category        Performance
# 0      Low   Senior  Needs Improvement
# 1      Low    Adult  Needs Improvement
# 2      Low    Adult  Needs Improvement
# 3      Low    Youth  Needs Improvement
# 4      Low    Adult               Good
# ..     ...      ...                ...
# 195   High    Adult               Good
# 196    Low    Youth               Good
# 197    Low    Youth  Needs Improvement
# 198   High    Adult          Excellent
# 199    Low    Adult  Needs Improvement
#
# [200 rows x 11 columns]

# %%
# 10. Update Age to 50 for rows where Group is "C" and Score is greater than 80.
df.loc[(df['Group'] == 'C') & (df['Score'] > 80), 'Age'] = 50
df
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 1      2    Person_2  46.0  New York  15.643704     B 2022-08-02       True
# 2      3    Person_3  32.0  New York  25.024290     B 2020-03-18       True
# 3      4    Person_4  25.0     Paris  54.922666     C 2021-12-30       True
# 4      5    Person_5  38.0    London  71.459592     D 2022-03-23       True
# ..   ...         ...   ...       ...        ...   ...        ...        ...
# 195  196  Person_196  34.0       nan  81.379502     A 2020-01-13      False
# 196  197  Person_197  19.0  New York  68.473117     A 2020-06-16       True
# 197  198  Person_198  19.0    Berlin  16.261694     D 2021-10-03      False
# 198  199  Person_199  45.0       nan  91.092718   VIP 2021-08-18       True
# 199  200         NaN  40.0  New York        NaN     B 2020-11-16       True
#
#     Status Category        Performance
# 0      Low   Senior  Needs Improvement
# 1      Low    Adult  Needs Improvement
# 2      Low    Adult  Needs Improvement
# 3      Low    Youth  Needs Improvement
# 4      Low    Adult               Good
# ..     ...      ...                ...
# 195   High    Adult               Good
# 196    Low    Youth               Good
# 197    Low    Youth  Needs Improvement
# 198   High    Adult          Excellent
# 199    Low    Adult  Needs Improvement
#
# [200 rows x 11 columns]

# %%
# 11. Sort the DataFrame by City alphabetically and by Age in descending order for rows where Score is above 70.
q11 = df[df['Score'] > 70].sort_values(by=['City', 'Age'], ascending=[True, False])
q11
# Out:
#       ID        Name        Age      City      Score Group  Join_Date  \
# 190  191  Person_191  56.000000    Berlin  97.439481   VIP 2020-09-17
# 180  181  Person_181  54.000000    Berlin  95.041148   VIP 2022-06-12
# 51    52   Person_52  52.000000    Berlin  96.119056   VIP 2020-12-28
# 157  158  Person_158  50.000000    Berlin  86.859913     C 2021-01-26
# 62    63   Person_63  46.000000    Berlin  84.487531     B 2021-09-22
# 83    84   Person_84  46.000000    Berlin  85.841275     B 2020-04-18
# 80    81   Person_81  43.000000    Berlin  77.641296     B 2021-01-28
# 8      9    Person_9  28.000000    Berlin  73.789692     B 2020-09-05
# 43    44   Person_44  26.000000    Berlin  94.023024   VIP 2021-11-29
# 107  108  Person_108  26.000000    Berlin  75.237453     C 2022-05-26
# 108  109  Person_109  25.000000    Berlin  79.157904     C 2022-08-23
# 176  177  Person_177  25.000000    Berlin  90.115801   VIP 2021-10-15
# 100  101  Person_101  22.000000    Berlin  95.060715   VIP 2021-11-22
# 164  165  Person_165  50.000000    London  89.114311     C 2021-02-13
# 143  144  Person_144  47.000000    London  90.635439   VIP 2020-01-04
# 162  163  Person_163  47.000000    London  96.987883   VIP 2021-10-06
# 136  137  Person_137  43.000000    London  75.337819     A 2022-07-08
# 7      8    Person_8  40.000000    London  95.486528   VIP 2022-03-04
# 14    15   Person_15  38.823529    London  75.784611     A 2020-12-15
# 74    75   Person_75  38.823529    London  75.061475     D 2021-06-20
# 134  135  Person_135  38.823529    London  94.724858   VIP 2020-08-16
# 4      5    Person_5  38.000000    London  71.459592     D 2022-03-23
# 135  136  Person_136  32.000000    London  98.600106   VIP 2021-07-01
# 49    50         NaN  24.000000    London  94.146481   VIP 2022-07-07
# 191  192  Person_192  19.000000    London  98.621074   VIP 2022-07-07
# 126  127  Person_127  18.000000    London  82.186006     B 2021-10-25
# 98    99   Person_99  52.000000  New York  95.006197   VIP 2021-09-04
# 120  121  Person_121  52.000000  New York  76.151063     C 2020-12-15
# 64    65   Person_65  43.000000  New York  81.446848     B 2020-01-28
# 86    87   Person_87  42.000000  New York  75.454287     C 2020-08-15
# 166  167  Person_167  42.000000  New York  99.296480   VIP 2022-04-15
# 154  155  Person_155  39.000000  New York  96.217255   VIP 2020-07-12
# 70    71   Person_71  32.000000  New York  73.507104     B 2020-03-26
# 124  125  Person_125  31.000000  New York  70.096913     D 2020-12-15
# 35    36   Person_36  24.000000  New York  85.648984     A 2020-01-28
# 127  128  Person_128  22.000000  New York  70.624223     A 2022-04-02
# 85    86   Person_86  18.000000  New York  75.087107     C 2020-04-20
# 75    76   Person_76  57.000000     Paris  80.683474     B 2020-05-24
# 130  131  Person_131  56.000000     Paris  98.663958   VIP 2022-06-17
# 140  141  Person_141  56.000000     Paris  77.714692     D 2021-04-12
# 181  182  Person_182  50.000000     Paris  89.026378     A 2020-05-18
# 69    70         NaN  48.000000     Paris  87.747201     D 2020-08-18
# 160  161  Person_161  45.000000     Paris  96.322254   VIP 2020-06-21
# 133  134  Person_134  32.000000     Paris  81.279957     B 2020-02-09
# 88    89   Person_89  26.000000     Paris  90.255291   VIP 2021-04-14
# 92    93   Person_93  25.000000     Paris  89.552323     A 2022-07-24
# 21    22   Person_22  19.000000     Paris  70.365786     B 2022-03-14
# 169  170         NaN  18.000000     Paris  96.930254   VIP 2020-08-12
# 82    83   Person_83  58.000000       nan  93.075733   VIP 2020-08-20
# 20    21   Person_21  55.000000       nan  85.546058     A 2020-01-26
# 115  116  Person_116  52.000000       nan  88.770418     B 2021-12-10
# 152  153  Person_153  49.000000       nan  74.604488     A 2021-07-27
# 198  199  Person_199  45.000000       nan  91.092718   VIP 2021-08-18
# 90    91   Person_91  41.000000       nan  82.645747     B 2021-09-14
# 76    77   Person_77  38.000000       nan  99.050514   VIP 2021-06-08
# 95    96   Person_96  34.000000       nan  90.538198   VIP 2021-08-17
# 195  196  Person_196  34.000000       nan  81.379502     A 2020-01-13
# 52    53   Person_53  31.000000       nan  90.535064   VIP 2022-01-20
# 109  110         NaN  29.000000       nan  78.961814     C 2022-01-10
# 71    72   Person_72  25.000000       nan  80.348093     A 2021-04-18
#
#      Is_Active Status Category Performance
# 190       True   High   Senior   Excellent
# 180       True   High   Senior   Excellent
# 51       False   High   Senior   Excellent
# 157      False   High   Senior        Good
# 62       False   High    Adult        Good
# 83        True   High    Adult        Good
# 80       False   High    Adult        Good
# 8        False    Low    Youth        Good
# 43        True   High    Youth   Excellent
# 107       True   High    Youth        Good
# 108       True   High    Youth        Good
# 176      False   High    Youth   Excellent
# 100       True   High    Youth   Excellent
# 164      False   High    Adult        Good
# 143       True   High    Adult   Excellent
# 162       True   High    Adult   Excellent
# 136      False   High    Adult        Good
# 7        False   High    Adult   Excellent
# 14        True   High    Adult        Good
# 74        True   High    Adult        Good
# 134       True   High    Adult   Excellent
# 4         True    Low    Adult        Good
# 135       True   High    Adult   Excellent
# 49       False   High    Youth   Excellent
# 191      False   High    Youth   Excellent
# 126       True   High    Youth        Good
# 98       False   High   Senior   Excellent
# 120      False   High   Senior        Good
# 64        True   High    Adult        Good
# 86        True   High    Adult        Good
# 166      False   High    Adult   Excellent
# 154      False   High    Adult   Excellent
# 70        True    Low    Adult        Good
# 124       True    Low    Adult        Good
# 35       False   High    Youth        Good
# 127      False    Low    Youth        Good
# 85       False   High    Youth        Good
# 75        True   High   Senior        Good
# 130       True   High   Senior   Excellent
# 140       True   High   Senior        Good
# 181      False   High    Adult        Good
# 69        True   High    Adult        Good
# 160      False   High    Adult   Excellent
# 133       True   High    Adult        Good
# 88        True   High    Youth   Excellent
# 92       False   High    Youth        Good
# 21       False    Low    Youth        Good
# 169       True   High    Youth   Excellent
# 82        True   High   Senior   Excellent
# 20        True   High   Senior        Good
# 115      False   High   Senior        Good
# 152      False    Low    Adult        Good
# 198       True   High    Adult   Excellent
# 90       False   High    Adult        Good
# 76       False   High    Adult   Excellent
# 95        True   High    Adult   Excellent
# 195      False   High    Adult        Good
# 52        True   High    Adult   Excellent
# 109       True   High    Youth        Good
# 71        True   High    Youth        Good

# %%
# 12. Sort rows based on the difference between Age and the mean Age of the dataset.
df['Age_Diff'] = abs(df['Age'] - df['Age'].mean())
q12 = df.sort_values(by='Age_Diff')
q12
# Out:
#       ID        Name        Age      City      Score Group  Join_Date  \
# 149  150         NaN  38.823529    London  11.881792     B 2021-05-18
# 179  180         NaN  38.823529       nan        NaN     D 2022-03-15
# 29    30         NaN  38.823529     Paris  61.585010     A 2020-10-29
# 119  120         NaN  38.823529    Berlin        NaN     C 2021-05-30
# 134  135  Person_135  38.823529    London  94.724858   VIP 2020-08-16
# ..   ...         ...        ...       ...        ...   ...        ...
# 126  127  Person_127  18.000000    London  82.186006     B 2021-10-25
# 121  122  Person_122  18.000000    Berlin  61.821806     C 2022-04-22
# 91    92   Person_92  18.000000     Paris  32.004960     D 2022-02-14
# 85    86   Person_86  18.000000  New York  75.087107     C 2020-04-20
# 169  170         NaN  18.000000     Paris  96.930254   VIP 2020-08-12
#
#      Is_Active Status Category        Performance   Age_Diff
# 149       True    Low    Adult  Needs Improvement   0.010882
# 179      False    Low    Adult  Needs Improvement   0.010882
# 29       False    Low    Adult               Good   0.010882
# 119       True    Low    Adult  Needs Improvement   0.010882
# 134       True   High    Adult          Excellent   0.010882
# ..         ...    ...      ...                ...        ...
# 126       True   High    Youth               Good  20.834412
# 121      False    Low    Youth               Good  20.834412
# 91       False    Low    Youth  Needs Improvement  20.834412
# 85       False   High    Youth               Good  20.834412
# 169       True   High    Youth          Excellent  20.834412
#
# [200 rows x 12 columns]

# %%
# 13. Find the total Score for each unique Group.
q13 = df.groupby('Group')['Score'].sum()
q13
# Out:
# Group
# A      2213.244265
# B      2240.200469
# C      1548.286682
# D      1226.350887
# VIP    2373.985508
# Name: Score, dtype: float64

# %%
# 14. Determine the average Age of Is_Active users grouped by City.
q14 = df[df['Is_Active']].groupby('City')['Age'].mean()
q14
# Out:
# City
# Berlin      37.470588
# London      37.048593
# New York    39.631579
# Paris       40.982353
# nan         44.550000
# Name: Age, dtype: float64

# %%
# 15. Filter the top 3 cities with the highest average Score.
q15 = df.groupby('City')['Score'].mean().nlargest(3)
q15
# Out:
# City
# nan       54.689360
# London    54.382431
# Paris     51.057153
# Name: Score, dtype: float64

# %%
# 16. Group by Group and find the percentage of rows in each group where Is_Active is True.
q16 = df.groupby('Group')['Is_Active'].mean() * 100
q16
# Out:
# Group
# A      43.137255
# B      60.784314
# C      52.380952
# D      48.387097
# VIP    60.000000
# Name: Is_Active, dtype: float64

# %%
# 17. Retrieve the 10th to 20th rows where Score is below the median score.
median_score = df['Score'].median()
q17 = df[df['Score'] < median_score].iloc[10:20]
q17
# Out:
#     ID       Name   Age      City      Score Group  Join_Date  Is_Active  \
# 18  19  Person_19  41.0    Berlin   4.072880     A 2021-07-26      False
# 22  23  Person_23  38.0    Berlin  47.417383     D 2020-09-13       True
# 23  24  Person_24  50.0    Berlin   9.783416     C 2020-01-08       True
# 24  25  Person_25  29.0     Paris  49.161588     A 2021-09-16      False
# 25  26  Person_26  39.0    Berlin  47.347177     C 2022-05-16      False
# 26  27  Person_27  42.0     Paris  17.320187     A 2020-09-09       True
# 27  28  Person_28  44.0    London  43.385165     B 2021-11-22       True
# 28  29  Person_29  59.0     Paris  39.850473     C 2021-12-19       True
# 31  32  Person_32  33.0    Berlin   4.530401     C 2020-02-25      False
# 32  33  Person_33  32.0  New York  37.461261     C 2021-12-26      False
#
#    Status Category        Performance   Age_Diff
# 18    Low    Adult  Needs Improvement   2.165588
# 22    Low    Adult  Needs Improvement   0.834412
# 23    Low    Adult  Needs Improvement  11.165588
# 24    Low    Youth  Needs Improvement   9.834412
# 25    Low    Adult  Needs Improvement   0.165588
# 26    Low    Adult  Needs Improvement   3.165588
# 27    Low    Adult  Needs Improvement   5.165588
# 28    Low   Senior  Needs Improvement  20.165588
# 31    Low    Adult  Needs Improvement   5.834412
# 32    Low    Adult  Needs Improvement   6.834412

# %%
# 18. Find rows at even-numbered indices where Age is greater than 40 and City is not null.
q18 = df.iloc[::2][(df['Age'] > 40) & (df['City'].notna())]
q18
# Out:
#       ID        Name   Age      City      Score Group  Join_Date  Is_Active  \
# 0      1    Person_1  56.0       nan  17.329432     A 2021-06-29       True
# 10    11   Person_11  41.0     Paris  61.172075     D 2020-04-30       True
# 12    13   Person_13  57.0       nan  24.773099     B 2020-08-26       True
# 18    19   Person_19  41.0    Berlin   4.072880     A 2021-07-26      False
# 20    21   Person_21  55.0       nan  85.546058     A 2020-01-26       True
# 26    27   Person_27  42.0     Paris  17.320187     A 2020-09-09       True
# 28    29   Person_29  59.0     Paris  39.850473     C 2021-12-19       True
# 30    31   Person_31  45.0    Berlin  63.509365     B 2021-09-30      False
# 34    35   Person_35  54.0    London  50.313626     A 2021-04-18       True
# 38    39   Person_39  56.0  New York   7.056875     C 2020-08-03       True
# 48    49   Person_49  45.0  New York  54.561679     C 2021-09-14      False
# 54    55   Person_55  53.0     Paris   6.936130     A 2020-09-30      False
# 60    61   Person_61  59.0    Berlin   7.118865     A 2020-07-10      False
# 62    63   Person_63  46.0    Berlin  84.487531     B 2021-09-22      False
# 64    65   Person_65  43.0  New York  81.446848     B 2020-01-28       True
# 80    81   Person_81  43.0    Berlin  77.641296     B 2021-01-28      False
# 82    83   Person_83  58.0       nan  93.075733   VIP 2020-08-20       True
# 86    87   Person_87  42.0  New York  75.454287     C 2020-08-15       True
# 90    91   Person_91  41.0       nan  82.645747     B 2021-09-14      False
# 98    99   Person_99  52.0  New York  95.006197   VIP 2021-09-04      False
# 102  103  Person_103  56.0     Paris  63.183721     C 2020-11-15       True
# 110  111  Person_111  51.0       nan   9.120610     B 2021-01-11       True
# 114  115  Person_115  54.0       nan  44.153050     B 2020-10-03      False
# 116  117  Person_117  57.0  New York  35.091501     B 2021-08-04       True
# 118  119  Person_119  44.0     Paris  14.299168     B 2021-09-15      False
# 120  121  Person_121  52.0  New York  76.151063     C 2020-12-15      False
# 122  123  Person_123  52.0       nan  10.112268     C 2021-03-21       True
# 128  129  Person_129  43.0    London   8.134878     D 2020-05-16      False
# 130  131  Person_131  56.0     Paris  98.663958   VIP 2022-06-17       True
# 136  137  Person_137  43.0    London  75.337819     A 2022-07-08      False
# 140  141  Person_141  56.0     Paris  77.714692     D 2021-04-12       True
# 144  145  Person_145  54.0     Paris  11.119748     D 2022-04-26      False
# 146  147  Person_147  56.0  New York   1.135364     D 2020-04-27      False
# 148  149  Person_149  46.0    Berlin   5.630328     B 2021-08-28       True
# 150  151  Person_151  53.0  New York  11.752625     A 2022-09-24      False
# 152  153  Person_153  49.0       nan  74.604488     A 2021-07-27      False
# 160  161  Person_161  45.0     Paris  96.322254   VIP 2020-06-21      False
# 162  163  Person_163  47.0    London  96.987883   VIP 2021-10-06       True
# 164  165  Person_165  50.0    London  89.114311     C 2021-02-13      False
# 166  167  Person_167  42.0  New York  99.296480   VIP 2022-04-15      False
# 168  169  Person_169  50.0    London  55.385428     D 2021-12-24      False
# 170  171  Person_171  44.0    Berlin  52.309784     D 2021-06-15       True
# 172  173  Person_173  58.0  New York  69.574869     D 2020-05-19      False
# 174  175  Person_175  56.0    Berlin  62.755808     C 2020-01-01       True
# 180  181  Person_181  54.0    Berlin  95.041148   VIP 2022-06-12       True
# 182  183  Person_183  59.0    Berlin  45.565675     B 2021-05-25       True
# 186  187  Person_187  49.0    London  46.369840     A 2021-11-03       True
# 188  189  Person_189  58.0  New York  58.365611     D 2021-11-20       True
# 190  191  Person_191  56.0    Berlin  97.439481   VIP 2020-09-17       True
# 198  199  Person_199  45.0       nan  91.092718   VIP 2021-08-18       True
#
#     Status Category        Performance   Age_Diff
# 0      Low   Senior  Needs Improvement  17.165588
# 10     Low    Adult               Good   2.165588
# 12     Low   Senior  Needs Improvement  18.165588
# 18     Low    Adult  Needs Improvement   2.165588
# 20    High   Senior               Good  16.165588
# 26     Low    Adult  Needs Improvement   3.165588
# 28     Low   Senior  Needs Improvement  20.165588
# 30     Low    Adult               Good   6.165588
# 34     Low   Senior  Needs Improvement  15.165588
# 38     Low   Senior  Needs Improvement  17.165588
# 48     Low    Adult  Needs Improvement   6.165588
# 54     Low   Senior  Needs Improvement  14.165588
# 60     Low   Senior  Needs Improvement  20.165588
# 62    High    Adult               Good   7.165588
# 64    High    Adult               Good   4.165588
# 80    High    Adult               Good   4.165588
# 82    High   Senior          Excellent  19.165588
# 86    High    Adult               Good   3.165588
# 90    High    Adult               Good   2.165588
# 98    High   Senior          Excellent  13.165588
# 102    Low   Senior               Good  17.165588
# 110    Low   Senior  Needs Improvement  12.165588
# 114    Low   Senior  Needs Improvement  15.165588
# 116    Low   Senior  Needs Improvement  18.165588
# 118    Low    Adult  Needs Improvement   5.165588
# 120   High   Senior               Good  13.165588
# 122    Low   Senior  Needs Improvement  13.165588
# 128    Low    Adult  Needs Improvement   4.165588
# 130   High   Senior          Excellent  17.165588
# 136   High    Adult               Good   4.165588
# 140   High   Senior               Good  17.165588
# 144    Low   Senior  Needs Improvement  15.165588
# 146    Low   Senior  Needs Improvement  17.165588
# 148    Low    Adult  Needs Improvement   7.165588
# 150    Low   Senior  Needs Improvement  14.165588
# 152    Low    Adult               Good  10.165588
# 160   High    Adult          Excellent   6.165588
# 162   High    Adult          Excellent   8.165588
# 164   High    Adult               Good  11.165588
# 166   High    Adult          Excellent   3.165588
# 168    Low    Adult  Needs Improvement  11.165588
# 170    Low    Adult  Needs Improvement   5.165588
# 172    Low   Senior               Good  19.165588
# 174    Low   Senior               Good  17.165588
# 180   High   Senior          Excellent  15.165588
# 182    Low   Senior  Needs Improvement  20.165588
# 186    Low    Adult  Needs Improvement  10.165588
# 188    Low   Senior  Needs Improvement  19.165588
# 190   High   Senior          Excellent  17.165588
# 198   High    Adult          Excellent   6.165588

# %%
# 19. Create a pivot table that shows the average Score for each Group and City combination.
q19 = df.pivot_table(values='Score', index='Group', columns='City', aggfunc='mean')
q19
# Out:
# City      Berlin     London   New York      Paris        nan
# Group
# A      28.950913  49.296816  41.139218  39.512041  61.487545
# B      57.003546  39.419061  45.494115  47.550532  40.398743
# C      45.032340  39.588352  42.206306  52.652287  38.759147
# D      32.108233  46.174640  35.848584  50.793684  33.627928
# VIP    94.633204  95.600338  96.839977  95.542939  92.858445

# %%
# 20. Reshape the dataset so that City becomes the index and Score becomes columns, with values being the mean score.
q20 = df.pivot_table(index='City', columns='Group', values='Score', aggfunc='mean')
q20
# Out:
# Group             A          B          C          D        VIP
# City
# Berlin    28.950913  57.003546  45.032340  32.108233  94.633204
# London    49.296816  39.419061  39.588352  46.174640  95.600338
# New York  41.139218  45.494115  42.206306  35.848584  96.839977
# Paris     39.512041  47.550532  52.652287  50.793684  95.542939
# nan       61.487545  40.398743  38.759147  33.627928  92.858445

# %%
# 1. Create a Multi-Level Index DataFrame and Retrieve Specific Data
# Question: Create a multi-level index DataFrame with "City" and "Year" as the index, then retrieve data for "New York" in 2021.

data = {'City': ['New York', 'New York', 'Los Angeles', 'Chicago', 'Houston'],
        'Year': [2020, 2021, 2021, 2022, 2022],
        'Population': [8000000, 8100000, 4000000, 2700000, 2300000]}
df = pd.DataFrame(data).set_index(['City', 'Year'])

result = df.loc[('New York', 2021)]
result
# Out:
# Population    8100000
# Name: (New York, 2021), dtype: int64

# %%
# 2. Reset and Rename Index
# Question: Reset the index of the above DataFrame and rename the "Year" column to "Census Year."
df_reset = df.reset_index()
df_reset.rename(columns={'Year': 'Census Year'}, inplace=True)
df_reset
# Out:
#           City  Census Year  Population
# 0     New York         2020     8000000
# 1     New York         2021     8100000
# 2  Los Angeles         2021     4000000
# 3      Chicago         2022     2700000
# 4      Houston         2022     2300000

# %%
# 3. Perform Grouping with Multiple Aggregations
# Question: Group the DataFrame by "City" and calculate the mean, sum, and standard deviation of the "Population."
df_grouped = df_reset.groupby('City').agg({'Population': ['mean', 'sum', 'std']})
df_grouped
# Out:
#             Population
#                   mean       sum           std
# City
# Chicago      2700000.0   2700000           NaN
# Houston      2300000.0   2300000           NaN
# Los Angeles  4000000.0   4000000           NaN
# New York     8050000.0  16100000  70710.678119

# %%
# 4. Create and Access Multi-Level Columns
# Question: Create a DataFrame with multi-level columns for "Math" and "Science" test scores. Retrieve all "Math" scores.

data = {('Math', 'Test1'): [85, 90], ('Math', 'Test2'): [88, 92],
        ('Science', 'Test1'): [75, 80], ('Science', 'Test2'): [78, 82]}
df_multi_col = pd.DataFrame(data, index=['Student1', 'Student2'])

math_scores = df_multi_col['Math']
math_scores
# Out:
#           Test1  Test2
# Student1     85     88
# Student2     90     92

# %%
# 5. Filter Rows Based on Multiple Conditions
# Question: Filter cities with a population greater than 4 million in 2021.

filtered = df_reset[(df_reset['Population'] > 4000000) & (df_reset['Census Year'] == 2021)]
filtered
# Out:
#        City  Census Year  Population
# 1  New York         2021     8100000

# %%
# 6. Add a Conditional Column
# Question: Add a column "Size" that labels cities as "Large" if the population is above 3 million, otherwise "Small."
df_reset['Size'] = np.where(df_reset['Population'] > 3000000, 'Large', 'Small')
df_reset
# Out:
#           City  Census Year  Population   Size
# 0     New York         2020     8000000  Large
# 1     New York         2021     8100000  Large
# 2  Los Angeles         2021     4000000  Large
# 3      Chicago         2022     2700000  Small
# 4      Houston         2022     2300000  Small

# %%
# 7. Pivot the DataFrame
# Question: Reshape the DataFrame so that "City" becomes the index, "Census Year" becomes columns, and "Population" becomes values.
pivoted = df_reset.pivot(index='City', columns='Census Year', values='Population')
pivoted
# Out:
# Census Year       2020       2021       2022
# City
# Chicago            NaN        NaN  2700000.0
# Houston            NaN        NaN  2300000.0
# Los Angeles        NaN  4000000.0        NaN
# New York     8000000.0  8100000.0        NaN

# %%
# 8. Melt the DataFrame
# Question: Convert the pivoted DataFrame back to long format.
melted = pd.melt(pivoted.reset_index(), id_vars=['City'], var_name='Year', value_name='Population')
melted
# Out:
#            City  Year  Population
# 0       Chicago  2020         NaN
# 1       Houston  2020         NaN
# 2   Los Angeles  2020         NaN
# 3      New York  2020   8000000.0
# 4       Chicago  2021         NaN
# 5       Houston  2021         NaN
# 6   Los Angeles  2021   4000000.0
# 7      New York  2021   8100000.0
# 8       Chicago  2022   2700000.0
# 9       Houston  2022   2300000.0
# 10  Los Angeles  2022         NaN
# 11     New York  2022         NaN

# %%
# 9. Handle Missing Data with Interpolation
# Question: Fill missing data in the pivoted DataFrame using linear interpolation.
pivoted_with_nan = pivoted.copy()
pivoted_with_nan.loc['Chicago', 2020] = np.nan
filled = pivoted_with_nan.interpolate(method='linear', axis=1)
filled
# Out:
# Census Year       2020       2021       2022
# City
# Chicago            NaN        NaN  2700000.0
# Houston            NaN        NaN  2300000.0
# Los Angeles        NaN  4000000.0  4000000.0
# New York     8000000.0  8100000.0  8100000.0

# %%
# 10. Perform Rolling Window Calculations
# Question: Add a column with the 3-period rolling mean of "Population."
df_reset['Rolling Mean'] = df_reset['Population'].rolling(window=3).mean()
df_reset
# Out:
#           City  Census Year  Population   Size  Rolling Mean
# 0     New York         2020     8000000  Large           NaN
# 1     New York         2021     8100000  Large           NaN
# 2  Los Angeles         2021     4000000  Large  6.700000e+06
# 3      Chicago         2022     2700000  Small  4.933333e+06
# 4      Houston         2022     2300000  Small  3.000000e+06

# %%
# 11. Resample a Time Series
# Question: Resample a time series to quarterly frequency and calculate the sum for each quarter.
date_rng = pd.date_range(start='2023-01-01', periods=12, freq='M')
values = np.random.randint(100, 200, size=len(date_rng))
df_time = pd.DataFrame({'Date': date_rng, 'Value': values}).set_index('Date')

resampled = df_time.resample('Q').sum()
resampled
# Out:
#             Value
# Date
# 2023-03-31    365
# 2023-06-30    477
# 2023-09-30    442
# 2023-12-31    469

# %%
# 12. Perform Shifting in Time Series
# Question: Add a column with the previous month's "Value."
df_time['Shifted'] = df_time['Value'].shift(1)
df_time
# Out:
#             Value  Shifted
# Date
# 2023-01-31    100      NaN
# 2023-02-28    145    100.0
# 2023-03-31    120    145.0
# 2023-04-30    189    120.0
# 2023-05-31    135    189.0
# 2023-06-30    153    135.0
# 2023-07-31    186    153.0
# 2023-08-31    156    186.0
# 2023-09-30    100    156.0
# 2023-10-31    162    100.0
# 2023-11-30    153    162.0
# 2023-12-31    154    153.0

# %%
# 13. Apply Complex Transformations with apply()
# Question: Add a column with square roots of "Population" using apply().
df_reset['Sqrt Population'] = df_reset['Population'].apply(np.sqrt)
df_reset
# Out:
#           City  Census Year  Population   Size  Rolling Mean  Sqrt Population
# 0     New York         2020     8000000  Large           NaN      2828.427125
# 1     New York         2021     8100000  Large           NaN      2846.049894
# 2  Los Angeles         2021     4000000  Large  6.700000e+06      2000.000000
# 3      Chicago         2022     2700000  Small  4.933333e+06      1643.167673
# 4      Houston         2022     2300000  Small  3.000000e+06      1516.575089

# %%
#14. Perform Index-Based Slicing
# Question: Slice data for cities from "Los Angeles" to "Houston" in the original multi-level index DataFrame.

#sliced = df.loc['Los Angeles':'Houston']
#sliced

# Sort the multi-level index
df_sorted = df.sort_index()

# Slice data for cities from "Los Angeles" to "Houston"
sliced = df_sorted.loc['Los Angeles':'Houston']
sliced
# Out:
# Empty DataFrame
# Columns: [Population]
# Index: []

# %%
# 15. Merge Two DataFrames
# Question: Merge two DataFrames on a shared column, keeping all rows from both DataFrames.

df1 = pd.DataFrame({'Key': [1, 2, 3], 'Value1': ['A', 'B', 'C']})
df2 = pd.DataFrame({'Key': [2, 3, 4], 'Value2': ['X', 'Y', 'Z']})
merged = pd.merge(df1, df2, on='Key', how='outer')
merged
# Out:
#    Key Value1 Value2
# 0    1      A    NaN
# 1    2      B      X
# 2    3      C      Y
# 3    4    NaN      Z

# %%
# 16. Align Overlapping Data
# Question: Merge two DataFrames and drop rows where no match is found.
aligned = pd.merge(df1, df2, on='Key', how='inner')
aligned
# Out:
#    Key Value1 Value2
# 0    2      B      X
# 1    3      C      Y

# %%
# 17. Filter Duplicates
# Question: Remove duplicate rows from the DataFrame.
df_duplicates = pd.DataFrame({'A': [1, 2, 2, 4], 'B': [5, 6, 6, 8]})
df_no_duplicates = df_duplicates.drop_duplicates()
df_no_duplicates
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 3  4  8

# %%
# 18. Forward and Backward Fill Missing Data
# Question: Fill missing values using forward fill.
df_missing = pd.DataFrame({'A': [1, np.nan, 3], 'B': [4, np.nan, 6]})
filled = df_missing.fillna(method='ffill')
filled
# Out:
#      A    B
# 0  1.0  4.0
# 1  1.0  4.0
# 2  3.0  6.0

# %%
# 19. Apply Multiple Aggregations to Specific Columns
# Question: Calculate both the sum and standard deviation of "Population" grouped by "City."
grouped = df_reset.groupby('City').agg({'Population': ['sum', 'std']})
grouped
# Out:
#             Population
#                    sum           std
# City
# Chicago        2700000           NaN
# Houston        2300000           NaN
# Los Angeles    4000000           NaN
# New York      16100000  70710.678119

# %%
# 20. Compare Vectorized vs. Loop Operations
# Question: Demonstrate the difference in execution time between vectorized operations and loops.
import time

large_df = pd.DataFrame({'A': np.random.randint(1, 100, 1000000),
                         'B': np.random.randint(1, 100, 1000000)})

start = time.time()
large_df['Sum_Vectorized'] = large_df['A'] + large_df['B']
print(f"Vectorized Time: {time.time() - start}")

start = time.time()
large_df['Sum_Loop'] = [row['A'] + row['B'] for _, row in large_df.iterrows()]
print(f"Loop Time: {time.time() - start}")
# Out:
# Vectorized Time: 0.007979154586791992
# Loop Time: 96.50773525238037

# %% [markdown]
# # --------------------------------END---------------------------------
