# %% [markdown]
# Hi everyone, good afternoon.
#
# Let me briefly introduce myself.
# My name is Harikrishna, and I’m working as a Software Developer
# in the AIS Reporting team.
#
# As most of you are aware, I mainly work with Sathiya.
#
# I’ll be conducting these Python sessions for our team.
#
# This training is completely beginner friendly,
# and will make every session simple and practical way.
#
# Before we start with today’s topics,
# does anyone have any questions?
#
# is everyone installed Jupyter extension? in VS Code

# %% [markdown]
# what is python
# 1. Python is easy for humans to understand because it looks close to normal English.
# You don’t need to write complex machine-level code.
# Examples:
# print("Hello")
# a = 10
# name = "Hari"
# total = a + 5
#
# 2. Python code is readable and easy to learn.
# It uses common English words instead of symbols.
# Examples:
# if age > 18:
# for i in range(5):
# print("Welcome")
# input("Enter name")
#
# 3. pyhton is a Interpreted language
#        Python runs code line by line.
# There is no need to compile the program before running.
# Examples:
# Errors are shown immediately
# Code runs directly using python file.py
# Easy testing in Python shell
# Faster debugging
#
# 4. Python can be used in many real-world areas.
# One language can solve different types of problems.
# Examples:
# Data Engineering (PySpark, Pandas)
# Web Development (Django, Flask)
# Automation scripts,
# Machine Learning & AI (PyTorch, Tensorflow)
#
# 5. Python programs run on different operating systems.
# Examples:
# Windows
# Linux
# macOS
# Cloud platforms (Azure, AWS)

# %% [markdown]
# '''
# Comments
# 1. Comments help programmers understand what the code is doing.
# # This is a comment
# # Printing message
# print("Hello")
#
# # storing age
# age = 25
# '''
# '''
# This is
# multi-line
# comment
# '''

# %%
# Indentation mainly used for defines the block of code
# Python uses spacess to group the statements to gether 
# this indentaion is mainly important while working with loops/ conditinal statements or functions or exception hadlings
age = 20

if age >= 18:
    print("Eligible for vote")
    print("You are an adult")

print("Program ended")
# Out:
# Eligible for vote
# You are an adult
# Program ended

# %%
# 1 and 2
a = 10        # int
b = 10.5      # float
c = "Python"  # string
d = True      # boolean

# 3 The value of a variable can be updated at any time.
x = 10
x = 20
x = x + 5
print(x)

# 5 rules are
# Variable name must start with a letter or underscore (_)
name = "Hari"
_age = 25
total = 100
# Variable name cannot start with a number
# Variable name can contain only letters, numbers, and underscore
student_name = "Ravi"
total_marks = 450
emp123 = 101
# Variable names cannot be Python keywords
class_no = 10
if_value = 5
for_count = 3
#Variable names are case-sensitive
# Out:
# 25

# %%
a = 47374562325667326526346236623623662366236236652356236234662346732
b = 3487263567235632656452367673246723646234623462364623462346236462346
print(a*b)
# Out:
# 165207585212033450726685146257290128428726041179000824574951813931392252372378807262544559870276940389902940529707176618298114153272
